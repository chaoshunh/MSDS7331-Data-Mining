# %%
# load the Titanic dataset
import pandas as pd
import numpy as np


df = pd.read_csv('../Dallas Crime/Data/Police_Incidents.csv',low_memory=False) # read in the csv file

df.head()
# Out:
#   Incident Number w/year  Year of Incident Service Number ID Watch  \
# 0            234975-2017              2017    234975-2017-01     1
# 1            179463-2017              2017    179463-2017-01     U
# 2            175975-2016              2016    175975-2016-01     1
# 3            072196-2016              2016    072196-2016-01     1
# 4            098976-2018              2018    098976-2018-01     2
#
#            Call (911) Problem                            Type of Incident  \
# 0         15 - ASSIST OFFICER      ASSAULT (AGG) -PUB SERV (AGG, LAW ENF)
# 1                  09V - UUMV  UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 2  6X - MAJOR DIST (VIOLENCE)                                         BMV
# 3                  09V - UUMV  UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 4     11C/01 - BURG COIN OPER         BURGLARY OF A COIN OPERATED MACHINE
#
#                Type  Location Type of Property       Incident Address  \
# 0  Highway, Street, Alley ETC              NaN                    NaN
# 1    Parking Lot (All Others)    Motor Vehicle       4500 LIVE OAK ST
# 2               Motor Vehicle    Motor Vehicle        3136 HUDNALL ST
# 3    Parking Lot (All Others)              NaN   3332 WEBB CHAPEL EXT
# 4                       Other              NaN  2215 GUS THOMASSON RD
#
#   Apartment Number                        ...                          \
# 0              NaN                        ...
# 1              NaN                        ...
# 2              NaN                        ...
# 3              NaN                        ...
# 4              NaN                        ...
#
#    NIBRS Code  NIBRS Group NIBRS Type             Update Date  X Coordinate  \
# 0         13A            A      Coded  10/24/2017 03:22:56 PM           NaN
# 1         240            A      Coded  08/14/2018 01:36:28 PM  2.498099e+06
# 2         NaN          NaN        NaN  07/28/2016 09:35:31 AM  2.482440e+06
# 3         NaN          NaN        NaN  08/14/2018 09:42:00 AM  2.470509e+06
# 4         23E            A      Coded  08/14/2018 12:20:55 PM  2.541731e+06
#
#     Y Cordinate Zip Code    City  State  \
# 0           NaN      NaN     NaN    NaN
# 1  6.978035e+06  75204.0  DALLAS     TX
# 2  6.986586e+06  75235.0  DALLAS     TX
# 3  7.000605e+06  75220.0  DALLAS     TX
# 4  6.977385e+06  75150.0  Dallas     TX
#
#                                            Location1
# 0                                                NaN
# 1  4500 LIVE OAK ST\nDALLAS, TX 75204\n(32.799576...
# 2  3136 HUDNALL ST\nDALLAS, TX 75235\n(32.823936,...
# 3  3332 WEBB CHAPEL EXT\nDALLAS, TX 75220\n(32.86...
# 4  2215 GUS THOMASSON RD\nDallas, TX 75150\n(32.7...
#
# [5 rows x 100 columns]

# %%
df.describe()
# Out:
#        Year of Incident  Reporting Area           Beat         Sector  \
# count     466173.000000   465186.000000  465961.000000  465969.000000
# mean        2016.129366     3134.475429     415.452141     411.498447
# std            1.868991     1828.081235     196.103547     196.195036
# min         2013.000000     1001.000000     111.000000       0.000000
# 25%         2015.000000     1245.000000     241.000000     240.000000
# 50%         2016.000000     3058.000000     417.000000     410.000000
# 75%         2017.000000     4321.000000     552.000000     550.000000
# max         2918.000000     9611.000000     757.000000     750.000000
#
#        Year1 of Occurrence  Day1 of the Year  Year2 of Occurrence  \
# count        466161.000000     466161.000000        466160.000000
# mean           2016.115074        186.243890          2016.122565
# std               1.323156         99.538326             1.311140
# min            1974.000000          1.000000          1989.000000
# 25%            2015.000000        106.000000          2015.000000
# 50%            2016.000000        191.000000          2016.000000
# 75%            2017.000000        264.000000          2017.000000
# max            2018.000000        366.000000          2018.000000
#
#        Day2 of the Year  Offense Entered Year  Offense Entered  Date/Time  \
# count     466160.000000         466173.000000               466173.000000
# mean         186.221149           2016.127206                  186.138989
# std           99.490009              1.308336                   99.422450
# min            1.000000           2014.000000                    1.000000
# 25%          106.000000           2015.000000                  106.000000
# 50%          191.000000           2016.000000                  191.000000
# 75%          264.000000           2017.000000                  264.000000
# max          366.000000           2018.000000                  366.000000
#
#           Victim Age  Victim Age at Offense  Victim Zip Code  Victim Package  \
# count  289282.000000          285848.000000    429730.000000             0.0
# mean       39.708509              39.564195     74671.793121             NaN
# std        15.282781              15.225201      5860.333996             NaN
# min         0.000000               0.000000         0.000000             NaN
# 25%        28.000000              27.000000     75210.000000             NaN
# 50%        37.000000              37.000000     75220.000000             NaN
# 75%        50.000000              50.000000     75237.000000             NaN
# max       950.000000             950.000000     99999.000000             NaN
#
#        Criminal Justice Information Service Code       UCR Code  X Coordinate  \
# count                               4.661730e+05  427895.000000  4.159590e+05
# mean                                4.954865e+07    1520.590049  2.494648e+06
# std                                 3.402783e+07    1265.255853  2.226260e+04
# min                                 9.990017e+06     110.000000  2.411659e+06
# 25%                                 2.299000e+07     640.000000  2.478019e+06
# 50%                                 2.999000e+07     710.000000  2.493388e+06
# 75%                                 1.000000e+08    2400.000000  2.507826e+06
# max                                 1.000000e+08    5700.000000  2.595095e+06
#
#         Y Cordinate       Zip Code
# count  4.159590e+05  462670.000000
# mean   6.978063e+06   75224.644193
# std    3.132856e+04      88.877731
# min    6.889043e+06   33019.000000
# 25%    6.954802e+06   75214.000000
# 50%    6.975493e+06   75224.000000
# 75%    7.001764e+06   75236.000000
# max    7.083051e+06   97224.000000

# %%
print (df.dtypes)
print (df.info())
# Out:
# Incident Number w/year                        object
# Year of Incident                               int64
# Service Number ID                             object
# Watch                                         object
# Call (911) Problem                            object
# Type of Incident                              object
# Type  Location                                object
# Type of Property                              object
# Incident Address                              object
# Apartment Number                              object
# Reporting Area                               float64
# Beat                                         float64
# Division                                      object
# Sector                                       float64
# Council District                              object
# Target Area Action Grids                      object
# Community                                     object
# Date1 of Occurrence                           object
# Year1 of Occurrence                          float64
# Month1 of Occurence                           object
# Day1 of the Week                              object
# Time1 of Occurrence                           object
# Day1 of the Year                             float64
# Date2 of Occurrence                           object
# Year2 of Occurrence                          float64
# Month2 of Occurence                           object
# Day2 of the Week                              object
# Time2 of Occurrence                           object
# Day2 of the Year                             float64
# Date of Report                                object
#                                               ...
# Victim Injury Description                     object
# Victim Condition                              object
# Modus Operandi (MO)                           object
# Family Offense                                object
# Hate Crime                                    object
# Hate Crime Description                        object
# Weapon Used                                   object
# Gang Related Offense                          object
# Victim Package                               float64
# Drug Related Istevencident                    object
# RMS Code                                      object
# Criminal Justice Information Service Code      int64
# Penal Code                                    object
# UCR Offense Name                              object
# UCR Offense Description                       object
#  UCR Code                                    float64
# Offense Type                                  object
# NIBRS Crime                                   object
# NIBRS Crime Category                          object
# NIBRS Crime Against                           object
# NIBRS Code                                    object
# NIBRS Group                                   object
# NIBRS Type                                    object
# Update Date                                   object
# X Coordinate                                 float64
# Y Cordinate                                  float64
# Zip Code                                     float64
# City                                          object
# State                                         object
# Location1                                     object
# Length: 100, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466173 entries, 0 to 466172
# Data columns (total 100 columns):
# Incident Number w/year                       466173 non-null object
# Year of Incident                             466173 non-null int64
# Service Number ID                            466173 non-null object
# Watch                                        466173 non-null object
# Call (911) Problem                           464310 non-null object
# Type of Incident                             466173 non-null object
# Type  Location                               454046 non-null object
# Type of Property                             113753 non-null object
# Incident Address                             462843 non-null object
# Apartment Number                             88706 non-null object
# Reporting Area                               465186 non-null float64
# Beat                                         465961 non-null float64
# Division                                     465961 non-null object
# Sector                                       465969 non-null float64
# Council District                             463049 non-null object
# Target Area Action Grids                     156133 non-null object
# Community                                    49819 non-null object
# Date1 of Occurrence                          466161 non-null object
# Year1 of Occurrence                          466161 non-null float64
# Month1 of Occurence                          466161 non-null object
# Day1 of the Week                             466161 non-null object
# Time1 of Occurrence                          466161 non-null object
# Day1 of the Year                             466161 non-null float64
# Date2 of Occurrence                          466160 non-null object
# Year2 of Occurrence                          466160 non-null float64
# Month2 of Occurence                          466160 non-null object
# Day2 of the Week                             466160 non-null object
# Time2 of Occurrence                          466160 non-null object
# Day2 of the Year                             466160 non-null float64
# Date of Report                               466173 non-null object
# Date incident created                        466173 non-null object
# Offense Entered Year                         466173 non-null int64
# Offense Entered Month                        466173 non-null object
# Offense Entered Day of the Week              466173 non-null object
# Offense Entered Time                         466173 non-null object
# Offense Entered  Date/Time                   466173 non-null int64
# CFS Number                                   464311 non-null object
# Call Received Date Time                      464311 non-null object
# Call Date Time                               464311 non-null object
# Call Cleared Date Time                       463972 non-null object
# Call Dispatch Date Time                      464267 non-null object
# Special Report (Pre-RMS)                     2712 non-null object
# Person Involvement Type                      449965 non-null object
# Victim Type                                  441694 non-null object
# Victim Name                                  446590 non-null object
# Victim Race                                  305597 non-null object
# Victim Ethnicity                             303071 non-null object
# Victim Gender                                305753 non-null object
# Victim Age                                   289282 non-null float64
# Victim Age at Offense                        285848 non-null float64
# Victim Home Address                          436525 non-null object
# Victim Apartment                             124818 non-null object
# Victim Zip Code                              429730 non-null float64
# Victim City                                  436023 non-null object
# Victim State                                 430999 non-null object
# Victim Business Name                         18629 non-null object
# Victim Business Address                      11919 non-null object
# Victim Business Phone                        6492 non-null object
# Responding Officer #1  Badge No              463741 non-null object
# Responding Officer #1  Name                  462949 non-null object
# Responding Officer #2 Badge No               168779 non-null object
# Responding Officer #2  Name                  168777 non-null object
# Reporting Officer Badge No                   464931 non-null object
# Assisting Officer Badge No                   353299 non-null object
# Reviewing Officer Badge No                   464208 non-null object
# Element Number Assigned                      463885 non-null object
# Investigating Unit 1                         343364 non-null object
# Investigating Unit 2                         343394 non-null object
# Offense Status                               456687 non-null object
# UCR Disposition                              456750 non-null object
# Victim Injury Description                    27133 non-null object
# Victim Condition                             22372 non-null object
# Modus Operandi (MO)                          441707 non-null object
# Family Offense                               466070 non-null object
# Hate Crime                                   584 non-null object
# Hate Crime Description                       466034 non-null object
# Weapon Used                                  394754 non-null object
# Gang Related Offense                         395292 non-null object
# Victim Package                               0 non-null float64
# Drug Related Istevencident                   466024 non-null object
# RMS Code                                     466173 non-null object
# Criminal Justice Information Service Code    466173 non-null int64
# Penal Code                                   466173 non-null object
# UCR Offense Name                             427895 non-null object
# UCR Offense Description                      427895 non-null object
#  UCR Code                                    427895 non-null float64
# Offense Type                                 427895 non-null object
# NIBRS Crime                                  192822 non-null object
# NIBRS Crime Category                         192822 non-null object
# NIBRS Crime Against                          192822 non-null object
# NIBRS Code                                   192822 non-null object
# NIBRS Group                                  192822 non-null object
# NIBRS Type                                   192822 non-null object
# Update Date                                  466173 non-null object
# X Coordinate                                 415959 non-null float64
# Y Cordinate                                  415959 non-null float64
# Zip Code                                     462670 non-null float64
# City                                         461271 non-null object
# State                                        461736 non-null object
# Location1                                    462843 non-null object
# dtypes: float64(15), int64(4), object(81)
# memory usage: 355.7+ MB
# None

# %%
df['Type of Incident'].unique()
# Out:
# array(['ASSAULT (AGG) -PUB SERV (AGG, LAW ENF)',
#        'UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE', 'BMV',
#        'BURGLARY OF A COIN OPERATED MACHINE', 'DEADLY CONDUCT',
#        'ASSAULT -OFFENSIVE CONTACT',
#        'MIR (MISCELLANEOUS INCIDENT REPORT NO OFFENSE)',
#        'BURGLARY OF HABITATION - FORCED ENTRY',
#        'ACCIDENT INV DAMAGE TO VEHICLE > OR EQUAL $200',
#        'CRIM MISCHIEF >OR EQUAL $100 BUT <$750', 'RECKLESS DAMAGE',
#        'CRIM MISCHIEF < $50', 'DWI W/OPEN CONTAINER',
#        'ROBBERY OF INDIVIDUAL', 'ROBBERY OF INDIVIDUAL (AGG)',
#        'BURGLARY OF HABITATION -NO FORCED ENTRY',
#        'THEFT OF PROP > OR EQUAL $2,500 <$30K (SHOPLIFT-NOT EMP) PC31.03 (e4A)',
#        'INJURED PERSON- PUBLIC PROPERTY (OTHER THAN FIREARM) (NO OFFENSE)',
#        'CRIM MISCHIEF > OR EQUAL $100 < $750',
#        'UNAUTHORIZED USE OF MOTOR VEH - TRUCK OR BUS',
#        'FAIL TO LEAVE ID AT SCENE OF ACCIDENT DAMAGE < $200',
#        'RECOVERED OUT OF TOWN STOLEN VEHICLE (NO OFFENSE)',
#        'TERRORISTIC THREAT - FEAR IMMINENT SBI',
#        'LOST PROPERTY (NO OFFENSE)', 'BURGLARY OF BUILDING - FORCED ENTRY',
#        'CRIM MISCHIEF > OR EQUAL $50 BUT < $500', 'THEFT FROM PERSON',
#        'FOUND PROPERTY (NO OFFENSE)', 'ACCIDENT INV DAMAGE TO VEHICLE',
#        'UNEXPLAINED DEATH (NO OFFENSE)', 'NATURAL DEATH (NO OFFENSE)',
#        'TRAF VIO - DUTY ON STRIKE FIXTURE/HWY LANDSCAPE> OR EQUAL $200',
#        'DUTY ON STRIKE UNATTENDED (PARKED) VEHICLE',
#        'CREDIT CARD OR DEBIT CARD ABUSE', 'UCR - THEFT OF BICYCLE',
#        'PUBLIC INTOXICATION', 'ASSAULT (AGG) -DEADLY WEAPON',
#        'DOG BITE - INJURED PERSON', 'HARASSMENT',
#        'BMV (OF AUTO ACCESSORY) (P.C. 30.04(A))',
#        'THEFT OF PROP > OR EQUAL $100 BUT <$750- NOT SHOPLIFT',
#        'UNLAWFUL POSS FIREARM BY FELON',
#        'FRAUD USE/POSS IDENTIFYING INFO # ITEMS < 5',
#        'THEFT OF PROP > OR EQUAL $50 BUT <$500 -SHOPLIFT (NOT EMP',
#        'ASSAULT -VERBAL THREAT', 'ABANDONED PROPERTY (NO OFFENSE)',
#        'BURGLARY OF BUILDING - NO FORCED ENTRY',
#        'THEFT OF PROP (AUTO ACC) $750 BUT <$2500 ENH - (NOT EMP)',
#        'THEFT OF PROP > OR EQUAL $2,500 BUT <$30K -SHOPLIFT(NOT EMP',
#        'CRIM MISCHIEF > OR EQUAL $500 BUT < $1,500',
#        'THEFT OF PROP > OR EQUAL $1,500 BUT  <$20K (BY EMPLOYEE)',
#        'THEFT OF PROP > OR EQUAL $50 BUT <$500- NOT SHOPLIFT',
#        'GRAFFITI PECUNIARY LOSS <$1500', 'MURDER',
#        'EVADING ARREST DETENTION', 'ASSAULT -BODILY INJURY ONLY',
#        'RECOVERED OUT OF TOWN STOLEN PROPERTY (NO OFFENSE)',
#        'THEFT OF PROP (AUTO ACC) <$100 - (NOT EMP)',
#        'TRAF VIO - DUTY ON STRIKE UNATTENDED (PARKED) VEHICLE >$200 DAMAGE',
#        'PROHIBITED WEAPON KNUCKLES',
#        'THEFT OF PROP > OR EQUAL $500 BUT <$1,500 -SHOPLIFT (NOT EMP',
#        'THREATENING PHONE CALLS',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2,500 BUT<$30K (NOT EMP',
#        'THEFT OF PROP > OR EQUAL $30K<$150K- NOT SHOPLIFT',
#        'DEADLY CONDUCT DISCHARGE FIREARM',
#        'TRAF VIO - DUTY ON STRIKE UNATTENDED (PARKED) VEHICLE< $200 DAMAG',
#        'THEFT OF PROP > OR EQUAL $2,500 <$30K (NOT SHOPLIFT) PC31.03(e4A)',
#        'POSS MARIJUANA <2OZ',
#        'THEFT OF PROP > OR EQUAL $2,500 BUT <$30K- NOT SHOPLIFT',
#        'THEFT OF PROP > OR EQUAL $750 BUT <$2,500 (NOT SHOPLIFT)',
#        'CRIM MISCHIEF >OR EQUAL $750 BUT <$2,500',
#        'CRIM MISCHIEF > OR EQUAL $1,500 BUT < $20K',
#        'THEFT OF PROP > OR EQUAL $500 BUT <$1,500 (NOT SHOPLIFT)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $750 BUT <$2,500 (NOT EMP',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $100 BUT<$750(NOT EMP',
#        'CRIM MISCHIEF >OR EQUAL $2,500 BUT <$30K',
#        'ILLEGAL DUMPING 1000 LBS OR MORE', 'ACCIDENTAL DEATH (NO OFFENSE)',
#        'DWI',
#        'THEFT OF PROP > OR EQUAL $100 <$750 (NOT SHOPLIFT) PC31.03(e2A)',
#        'ATTACK BY DANGEROUS DOG', 'THEFT OF FIREARM',
#        'UNAUTHORIZED USE OF MOTOR VEH - (ATT) TRUCK OR BUS',
#        'BURGLARY OF HABITATION (ATT)',
#        'POSS CONT SUB PEN GRP 1 > OR EQUAL 1G<4G',
#        'FORGERY TO DEFRAUD OR HARM OF ANOTHER', 'CRIMINAL TRESPASS',
#        'THEFT OF PROP <$50 - OTHER THAN SHOPLIFT',
#        'THEFT OF PROP <$100 - OTHER THAN SHOPLIFT',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $500 BUT <$1,500 (NOT EMP',
#        'THEFT OF MATERIAL 50% ALUM/BRNZE/COPPER <$20K',
#        'DISCHARGE FIREARM IN CERTAIN MUNICIPALITIES',
#        'BURGLARY OF HABITATION INTEND TO COMMIT SIMPLE ASSAULT',
#        'CRIM MISCHIEF <$100',
#        'THEFT OF PROP > OR EQUAL $750 BUT <$2,500 -SHOPLIFT (NOT EMP',
#        'ROBBERY OF BUSINESS (AGG)',
#        'THEFT OF PROP > OR EQUAL $100 BUT <$750 -SHOPLIFT (NOT EMP',
#        'FORGERY FINANCIAL INSTRUMENT',
#        'THEFT OF PROP > OR EQUAL $20K<$100K- NOT SHOPLIFT',
#        'ACCIDENT INVOLVING INJURY', 'TRAFFIC VIOLATION - HAZARDOUS',
#        'TRAF VIO -DUTY ON STRIKE UNATTENDED VEH > OR EQUAL $200',
#        'FLEEING POLICE OFFICER',
#        'THEFT OF PROP > OR EQUAL $1,500 BUT <$20K- NOT SHOPLIFT',
#        'THEFT OF PROP > OR EQUAL $750 <$2,500 (NOT SHOPLIFT) PC31.03(e3)',
#        'THEFT OF SERVICE > OR EQUAL $500 BUT <$1,500',
#        'THEFT OF PROP > OR EQUAL $500 BUT <$1,500 (BY EMPLOYEE)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $1,500 BUT<$20K (NOT EMP',
#        'UNAUTHORIZED USE OF MOTOR VEH - OTHER VEH',
#        'ASSAULT (AGG) -DISCH FIREARM  OCC BLDG/HOUSE/VEH (AGG)',
#        'UCR - DEADLY CONDUCT',
#        'THEFT OF PROP <$50 -SHOPLIFTING - (NOT BY EMPLOYEE)',
#        'THEFT OF PROP > OR EQUAL $2,500 BUT  <$30K (BY EMPLOYEE)',
#        'ARSON -ALL OTHER STRUCTURES - INHABITED',
#        'THEFT OF PROP <$100 -SHOPLIFTING - (NOT BY EMPLOYEE)',
#        'CRIMINAL TRESPASS HAB/DEADLY WEAP/INFRASTRUC',
#        'ARSON -SINGLE RESIDENCE INHABITED',
#        'FALSE ALARM OR REPORT EMERGENCY',
#        'THEFT OF MATERIAL ALUM/BRNZE/COPPER <$20K PC31.03(e4F)',
#        'ACCIDENT INVOLVING SERIOUS BODILY INJURY',
#        'THEFT OF SERVICE > OR EQUAL $100 BUT <$750',
#        'THEFT OF SERVICE < $100',
#        'THEFT OF PROP <$1,500 2+ PREV CONVIC -SHOPLFT-(NOT EMP)',
#        'ASSAULT (AGG) -SERIOUS BODILY INJURY',
#        'TAMPER FABRICATE PHYSICAL EVID WITH INTENT TO IMPAIR',
#        'THEFT OF PROP > OR EQUAL $30K<$150K (BY EMPLOYEE)',
#        'INJURED PERSON - AT HOME (OTHER THAN FIREARM) (NO OFFENSE)',
#        'UNAUTHORIZED USE OF MOTOR VEH - (ATT) AUTOMOBILE',
#        'THEFT OF PROP <$50 (BY EMPLOYEE)',
#        'SEX OFFENDERS DUTY TO REGISTER LIFE/ANNUALLY',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $50 BUT<$500(NOT EMP',
#        'FRAUD DESTROY REMOVAL CONCEALMENT WRITING',
#        'THEFT OF PROP > OR EQUAL $100 <$750 (SHOPLIFT-NOT EMP) PC31.03(e2A)',
#        'UCR- THEFT FROM BUILDING', 'HARASSMENT OF PUBLIC SERVANT',
#        'THEFT OF PROP (ATT) > OR EQUAL $50 BUT <$500 (NOT EMP',
#        'CRUELTY TO NON-LIVESTOCK ANIMAL-TORTURE',
#        'THEFT OF PROP > OR EQUAL $50 BUT <$500 (BY EMPLOYEE)',
#        'UCR - BMV- STOLEN PROP/DAMAGE COLUMN/IGNITION - AUTO (UCR PURPOSES ONLY)',
#        'RIOT PARTICIPATION MB', 'OBSTRUCT HIGHWAY PASSAGEWAY',
#        'FRAUD USE/POSS IDENTIFYING INFO # ITEMS 10<50',
#        'UCR - THEFT OF PROPERTY', 'BURGLARY OF BUILDING (ATT)',
#        'THEFT OF PROP (AUTO ACC) $500 BUT <$1500 ENH - (NOT EMP)',
#        'THEFT OF PROP <$2500 2+ PREV CONVIC -SHOPLFT-(NOT EMP)',
#        'TAKE WEAPON FROM AN OFFICER (ATT)',
#        'BURGLARY OF HABITATION INTEND TO COMMIT AGG ASSAULT',
#        'SALE TO MINORS - ALCOHOL',
#        'THEFT OF PROP > OR EQUAL $100 BUT <$750 (BY EMPLOYEE)',
#        'ASSAULT -PUB SERV (LAW ENF) - BODILY INJURY ONLY',
#        'POSS CONT SUB PEN GRP 1 <1G',
#        'THEFT OF PROP >$750 BUT <$2500 ENH -SHOPLIFT-NOT BY EMP',
#        'CRIM MISCHIEF > OR EQUAL $2,500 < $30K',
#        'POSS CONT SUB PEN GRP 2 < 1G',
#        'THEFT OF PROP <$2500 2+ CONV ENH-SHOPLIFT - (NOT EMP)',
#        'POSS CONT SUB PEN GRP 3 < 28G',
#        'TRAF VIO -OPERATE MOTOR VEH W/O FIN RESP',
#        'EVADING ARREST DETENTION W/VEH', 'ROBBERY OF BUSINESS',
#        'INTERFERE W/ CHILD CUSTODY', 'TRAFFIC VIOLATION - NON HAZARDOUS',
#        'FORGERY GOVT/NATIONAL INST/MONEY/SECURITY',
#        'GRAFFITI >OR EQUAL $2500 BUT <$30K',
#        'TRAF VIO -DRIV W/OUT LIC INV W/PREV CONV/SUSP/W/O FIN RES',
#        'INJURED PERSON - FIREARM INJURY (NO OFFENSE)',
#        'GRAFFITI WORSHIP BURIAL/PUBLIC MONUMENT/SCHOOL',
#        'FAIL TO ID -FUGITIVE FROM JUSTICE',
#        'CREDIT CARD OR DEBIT CARD ABUSE ELDERLY',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2,500 <$30K (NOT EMP) PC31.03(e4A)',
#        'THEFT OF PROP >$100 BUT <$750 ENH -SHOPLIFT - NOT BY EMP',
#        'EVADING ARREST DETENTION W/VEHICLE PC38.04(b)(2)(A)',
#        'DISORDERLY CONDUCT DISCHARGE/DISPLAY FIREARM',
#        'DECEPTIVE BUSINESS PRACTICE', 'GRAFFITI >OR EQUAL $100 BUT <$750',
#        'TRAF VIO - DUTY ON STRIKING UNATTENDED VEH', 'ATTACK BY DOG SBI',
#        'THEFT OF SERVICE < $20',
#        'EVADING ARREST DET W/VEH W/ PREV CONV OR S.B.I.',
#        'THEFT OF PROP (AUTO ACC) <$50 - (NOT EMP)',
#        'CRIM MISCHIEF >OR EQUAL $750 < $2,500', 'DWI 2 OR MORE PREV CONV',
#        'THEFT OF PROP $100 BUT <$750 ENH-NOT SHOPLIF',
#        'THEFT OF PROP (ATT) <$100 (NOT  EMPLOYEE)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $2500 < $30K',
#        'TRAFFIC FATALITY- NOT DWI- UNINTENTIONAL (NO OFFENSE)',
#        'CRIMINAL TRESPASS WARNING', 'UNLAWFUL CARRYING WEAPON',
#        'THEFT OF SERVICE > OR EQUAL $2,500 BUT <$30K',
#        'THEFT OF PROP > OR EQUAL $750 BUT <$2,500 (BY EMPLOYEE)',
#        'CRIM MISCHIEF IMPAIR/INTERRUPT PUB SERVICE',
#        'ACCIDENT INVOLVING DEATH',
#        'COMPUTER SECURITY BREACH >OR EQUAL TO $150K BUT <$300K',
#        'THEFT OF PROP > OR EQUAL $2,500 <$30K (EMPLOYEE) PC31.03(e4A)',
#        'THEFT OF PROP $50 BUT <$500 ENH-NOT SHOPLIF', 'ARSON -MOTOR VEH',
#        'TAMPER W/GOVT REC-INS DOC (A)(2,5)',
#        'INJURED PERSON - OCCUPATIONAL (OTHER THAN FIREARM) (NO OFFENSE)',
#        'THEFT OF PROP <$100 (BY EMPLOYEE)',
#        'INTOXICATION ASSAULT W/VEH SERIOUS BODILY INJURY',
#        'TRAF VIO - RACING ON HIGHWAY CAUSING BODILY INJURY',
#        'OBSTRUCTION OR RETALIATION',
#        'ILLEGAL DUMPING > OR EQUAL 500LBS < 1000 LBS', 'DWI 1 PREV CONV',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $1500 BUT<$20K ENH(NOT EMP)',
#        'THEFT FROM PERSON-PICKPOCKE',
#        'ARSON -(W BODILY INJURY OR DEATH)-SINGLE RES-INHABITED',
#        'VIO BOND/PROTECTIVE ORDER', 'POSS MARIJUANA <2OZ *DRUG FREE ZONE*',
#        'TAMPER W/GOVT REC-INS DOC-DEFRAUD/HARM', 'STALKING',
#        'EVADING ARREST DETENTION W/PREV CONVICTION',
#        'UNAUTHORIZED USE OF MOTOR VEH - (ATT) OTHER VEH',
#        'UCR - ASSAULT (AGG) M/V',
#        'THEFT OF PROP (AUTO ACC) $50 BUT <$500 ENH - (NOT EMP',
#        'POSS MARIJUANA >2OZ< OR EQUAL 4OZ',
#        'THEFT OF PROP (ATT) > OR EQUAL $2,500 BUT <$30K (BY EMP',
#        'ARSON -COMMUNITY/PUBLIC - INHABITED',
#        'TRAF VIO -DUTY ON STRIKE FIX/HWY LANDSCAPE > OR EQUAL $200 TC 550.025(b)2',
#        'THEFT OF PROP (ATT) <$100 (BY EMPLOYEE)', 'BMV (ATT)',
#        'DELIVERY MARIJUANA < OR EQUAL 1/4 OZ', 'ARSON -ALL OTHERS',
#        'THEFT OF SERVICE > OR EQUAL $750 BUT <$2,500',
#        'DWI BAC > OR EQUAL TO 0.15', 'FALSE ALARM OR REPORT',
#        'THEFT OF PROP > OR EQUAL $1,500 BUT <$20K -SHOPLIFT(NOT EMP',
#        'TRAF VIO - RACING ON HIGHWAY',
#        'THEFT OF PROP $750 BUT <$2500 ENH (BY EMPLOYEE)',
#        'FRAUD USE/POSS IDENT INFO # ITEMS <5 ELDERLY',
#        'THEFT OF SERVICE > OR EQUAL $20 BUT <$500',
#        'GRAFFITI PECUNIARY LOSS <$500', 'THEFT FROM PERSON-PURSE SNATC',
#        'ALARM INCIDENT REPORT (NO OFFENSE)', 'INTERFERE W/ PUBLIC DUTIES',
#        'ILLEGAL DUMPING >5 LBS < 500 LBS',
#        'TRAF VIO - DUTY ON STRIKE FIXTURE/HWY LANDSCAPE< $200',
#        'ARSON -ALL OTHER STRUCTURES - UNINHABITED',
#        'CRUELTY TO NON-LIVESTOCK ANIMALS TORTURE',
#        'TRAF VIO - RACING ON HIGHWAY CAUSING SERIOUS BODILY INJ',
#        'IMPERSONATE PUBLIC SERVANT',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT> $2,500 < $30K PC32.32(c4)',
#        'DWI W/CHILD UNDER 15 YOA',
#        'ASSAULT -ELD OR DISABLED VIC -BODILY INJURY ONLY',
#        'THEFT OF PROP $500 BUT <$1500 ENH  -NOT SHOPLIFT',
#        'THEFT OF PROP >$500 BUT <$1500 ENH -SHOPLIFT-NOT BY EMP',
#        'ARSON -OTHER RESIDENCE - UNINHABITED',
#        'CRIM MISCHIEF IMP/INT PUB SERVICE <$20,000',
#        'MAN DEL CONT SUB PEN GRP 1 <1G',
#        'THEFT OF DL/COMM DL/ID CERTIFICATE',
#        'GRAFFITI >OR EQUAL $750 BUT <$2500',
#        'RESTRICTION ON CONSUMPTION OF ALCOHOL',
#        'TAMPER W/GOVT RECORD LIC/SEAL DEFRAUD/HARM',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $100 <$750 (NOT EMP)PC31.03(e2A)',
#        'MAN DEL CONT SUB PEN GRP 1 > OR EQUAL 4G<200G',
#        'TAMPER W/GOVT REC-INS DOC (A)(1,3,4,6)',
#        'TERRORISTIC THREAT - REACTION EMERGENCY AGENCY',
#        'POSS CONT SUB PEN GRP 2 > OR EQUAL 4G<400G',
#        'THEFT OF PROP $750 BUT <$2500 ENH  -NOT SHOPLIFT',
#        'TERRORISTIC THREAT INTERRUPT PUBLIC PLACE',
#        'CRIM MISCHIEF > OR EQUAL $100K BUT < $200K',
#        'FRAUD USE/POSS IDENTIFYING INFO # ITEMS 5<10',
#        'FRAUD USE/POSS IDENTIFYING INFO # ITEMS 50 OR MORE',
#        'ASSAULT (AGG) -RETALIATION (AGG)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $20K < $100K',
#        'BMV (ATT) (OF AUTO ACCESSORY) (P.C. 30.04(A))',
#        'THEFT FROM PERSON (ATT) PURSE SNATCH', 'PLACE WEAPONS PROHIBITED',
#        'CRIM MISCHIEF >$750  BUT <$30K DESTROY SCHOOL',
#        'CRIM MISCHIEF DAMAGE/DESTR WORSHIP/SCHOOL',
#        'ASSAULT -PUB SERV (NON LAW ENF) - BODILY INJURY ONLY',
#        'CONTINUOUS VIOLENCE AGAINST THE FAMILY',
#        'FRAUD USE/POSS IDENT INFO # ITEMS 5<10 ELDERLY',
#        'POSS OF CHILD PORNOGRAPHY',
#        'CAPITAL MURDER BY TERROR THREAT/OTHER FELONY',
#        'MAN DEL CONT SUB PEN GRP 1 > OR EQUAL 400G',
#        'FORGERY TO DEFRAUD OR HARM ELDERLY',
#        'THEFT OF PROP <$2500 2/MORE PREV CONV - NOT SHOPLIFT',
#        'ASSAULT (AGG) -AGAINST SECURITY OFF (AGG)',
#        'THEFT OF PROP > OR EQUAL $1500 BUT <$20K ENH -NOT SHOPLIFT',
#        'FRAUD INTENT OBTAIN PRESCRIPTION NOT MED NEEDED SCHEDULE',
#        'THEFT OF PROP (ATT) > OR EQUAL $1,500 BUT <$20K (NOT EMP',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2,500 BUT <$30K(BY EMP',
#        'CAPITAL MURDER OF MULTIPLE PERSONS',
#        'POSS CONT SUB PEN GRP 1 <1G *DRUG FREE ZONE*',
#        'THEFT OF PROP (ATT) > OR EQUAL $100K<$200K (NOT EMP)',
#        'CRUELTY TO LIVESTK ANIM-TORTURE',
#        'MAN DEL CONT SUB PEN GRP 1 > OR EQUAL 200G <400G',
#        'LABELING UNAUTHORIZED RECORDING 65+ W/I 180D/PREV CONV',
#        'FRAUD INTENT OBTAIN PRESCRIP NOT MED NEEDED SCHED LLL OR I',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $500 BUT <$1,500-(BY EMP',
#        'MANSLAUGHTER (TRAFFIC FATALITY)',
#        'POSS CONT SUB PEN GRP 2-A  2 OZ OR LESS',
#        'THEFT FROM PERSON (ATT) PICKPOCKET',
#        'THEFT OF PROP >$50 BUT <$500 ENH -SHOPLIFT - NOT BY EMP',
#        'GRAFFITI PECUNIARY LOSS <$100',
#        'FORGERY GOVT/NATION INST/MONEY/SECURITY ELDER',
#        'THEFT OF PROP (ATT) > OR EQUAL $100 BUT <$750 (NOT EMP',
#        'GAMBLING PROMOTION', 'ARSON -OTHER COMMERCIAL - UNINHABITED',
#        'CURFEW VIOLATION',
#        'THEFT OF PROP > OR EQUAL $150K<$300K (BY EMPLOYEE)',
#        'ARSON -OTHER RESIDENCE INHABITED',
#        'THEFT OF PROP $50 BUT <$500 ENH (BY EMPLOYEE)',
#        'THEFT OF SERVICE > OR EQUAL $750 <$2,500 PC31.04(e3)',
#        'THEFT OF PROP > OR EQUAL $750 <$2,500 (SHOPLIFT-NOT EMP) PC31.03(e3)',
#        'THEFT OF PROP (ATT) $500 BUT <$1500 ENH(NOT EMPLOYEE)',
#        'TRADEMARK COUNTERFEITING > OR EQUAL TO $1,500 BUT < $20K',
#        'CRIM MISCHIEF > OR EQUAL $20K BUT < $100K', 'KIDNAPPING (AGG) -',
#        'ASSAULT -SPORTS PARTICIPANT VICTIM',
#        'BMV <$1,500  2/MORE PREV CONV- (NOT EMPLOYEE)',
#        'THEFT OF PROP > OR EQUAL $100K<$200K-OTHER THAN SHOPLIFT',
#        'THEFT OF PROP <$100 ENH -SHOPLIFTING -  (NOT BY EMP)',
#        'CRIM MISCHIEF >OR EQUAL $30K BUT <$150K',
#        'FORGERY FINANCIAL INSTRUMENT ELDERLY',
#        'FALSE REPORT TO POLICE OFFICER/LAW ENFORCE EMPL',
#        'THEFT OF PROP <$100 W/PREV CONVIC -SHOPLIFT-(NOT BY EMP)',
#        'FORGING OR ALTERING PRESCRIPTION',
#        'THEFT OF PROP <$1500 2+ CONV ENH-SHOPLIFT - (NOT EMP)',
#        'ESCAPE WHILE ARRESTED/CONFINED FELONY',
#        'BMV (ENCLOSED RAIL CAR) - NO FORCED ENTRY',
#        'TRAF VIO -DUTY ON STRIKE UNATTENDED VEH < $200',
#        'THEFT OF PROP <$1500 2+ CONV ENH  - NOT SHOPLIFT',
#        'THEFT OF PROP (ATT) <$50 (NOT  EMPLOYEE)',
#        'CRIM MISCHIEF IMP/INT PUB SERVICE <$30,000',
#        'FRAUD POSS PRESRCIPTION FORMS SCHEDULE LV OR V CONT SUBS',
#        'POSS MARIJUANA >4OZ< OR EQUAL 5LBS',
#        'FRAUD INTENT OBTAIN PRESCRIP NOT MED NEEDED SCHED I OR I',
#        'TAMPER W/GOVT RECORD DEFRAUD/HARM',
#        'THEFT OF PROP > OR EQUAL $750 <$2,500 (EMPLOYEE) PC 31.03(e3)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $30K < $150K',
#        'INJURY CHILD/ELDERLY/DISABLED-INT-BODILY INJURY-HEALTH CAR',
#        'UNL INTER/USE/DISC WIRE/ORAL ELEC COMMUNICATE',
#        'RESIST ARREST SEARCH OR TRANSPORT',
#        'ARSON -(WITH BODILY INJURY OR DEATH) - ALL OTHERS',
#        'POSS MARIJUANA >4OZ< OR EQUAL 5LBS *DRUG FREE ZONE*',
#        'THEFT OF PROP <$1,500 2/MORE PREV CONV - NOT SHOPLIFT',
#        'THEFT OF PROP (AUTO ACC) <$100 ENH - (NOT EMP)',
#        'BURGLARY OF HABITATION INTEND TO COMMIT ROBBERY',
#        'THEFT OF PROP > OR EQUAL $20 BUT <$500 BY CHECK',
#        'THEFT OF PROP > OR EQUAL $20K<$100K (BY EMPLOYEE)',
#        'POSS CONT SUB PEN GRP 1 > OR EQUAL 200G<400G',
#        'CRIMINAL NEGLIGENT HOMICIDE', 'WARRANT HOLD (OUTSIDE AGENCY)',
#        'TAMPER W/GOVT RECORD', 'ARSON -STORAGE - UNINHABITED',
#        'THEFT OF MATERIAL 50% ALUM/BRNZE/COPPER <$20K ENH',
#        'ABUSIVE/SILENT CALLS TO 911 SERVICE',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $30K<$150K - (NOT  EMP',
#        'UNLAWFUL RESTRAINT', 'FICTITIOUS LICENSE PLATE',
#        'THEFT OF PROP (AUTO ACC) <$100  - (BY EMPLOYEE)',
#        'THEFT OF PROP (AUTO ACC) <$50 ENH - (NOT EMP)',
#        'TRAF VIO -RACING ON HIGHWAY CAUSING SERIOUS BODILY INJ',
#        'UCR -THEFT OF PROPERTY',
#        'THEFT OF CARGO > OR EQUAL $10K < $100K (EMP) PC31.18(c2)',
#        'ARSON -OTHER COMMERCIAL - INHABITED',
#        'EVADING ARREST DET W/VEH/WTRCFT W/PREV CONV OR SBI PC38.04(b2A,B)',
#        'CRIM MISCHIEF $1500  BUT < $20K DESTROY SCHOOL',
#        'THEFT OF SERVICE > OR EQUAL $1,500 BUT <$20K',
#        'ASSAULT -OF SECURITY OFFICER - BODILY INJURY ONLY',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $750 <$2,500 (NOT EMP) PC31.03 (e3)',
#        'CRIMINAL SIMULATION',
#        'ASSAULT -EMS PERSONNEL PROVIDING SER - BODILY INJURY ONLY',
#        'EVADING ARREST DETENTION W/VEHICHLE PC38.04(b)(2)(A)',
#        'PROHIBITED WEAPON PC', 'TERRORISTIC THREAT FEAR IMMINENT SBI',
#        'ONLINE IMPERSONATION-NAME/PERSONA TO CREATE PAGE',
#        'ARSON -SINGLE RESIDENCE UNINHABITED',
#        'FRAUDULENT FILING OF FINANCING STATEMENT',
#        'THEFT FROM PERSON ENHANCED',
#        'THEFT ORG RETAIL -(NOT EMP)> $1500<$20,000',
#        'THEFT OF PROP (AUTO ACC) $100 BUT <$750 ENH - (NOT EMP',
#        'FAIL TO ID -FUGITIVE INTENT GIVE FALSE INFO',
#        'HINDER APPREHENSION/PROSECUTION',
#        'THEFT OF PROP > OR EQUAL $750 <$2,500 ENH (NOT SHOPLIFT) PC31.03(f)',
#        'THEFT OF FIREARM ENHANCED',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $100 <$750 (EMP) PC31.03(e2A)',
#        'HOAX BOMB WEAPONS FREE ZONE',
#        'THEFT OF PROP <$50 ENH -SHOPLIFTING -  (NOT BY EMP)',
#        'FRAUD DELIVERS PRESCRIPTION FORMS SCHEDULE II CONT SUBS',
#        'THEFT OF PROP > OR EQUAL $2500 BUT <$30K ENH -NOT SHOPLIFT',
#        'WARRANT-DALLAS PD (ALIAS/CAPIAS)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT >$300K',
#        'THEFT OF PROP $20 BUT <$500 BY CHECK ENH',
#        'MAN DEL CONT SUB PEN GRP 2 > OR EQUAL 4G<400G',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $1,500 BUT <$20K(BY EMP',
#        'THEFT OF PROP > OR EQUAL $20K<$100K ENH- NOT SHOPLIFT',
#        'SEX OFFENDERS DUTY TO REGISTER W/PREV CONV',
#        'FAIL TO ID -GIVING FALSE/FICTITIOUS INFO PC 38.02(c)(2)',
#        'DISRUPTION OF CLASSES',
#        'THEFT OF PROP > OR EQUAL $150K<$300K-OTHER THAN SHOPLIFT',
#        'CRUELTY TO LIVESTK ANIM-FAIL TO PROVIDE-W/2 PREV CON',
#        'CRIM MISCHIEF <$2500 HABITATION FA/EXPLOS',
#        'THEFT OF SERVICE (ATT) < $20',
#        'THEFT OF MATERIAL 50% ALUM/BRNZE/COPPER  (ATT) <$20K',
#        'THEFT OF PROP > OR EQUAL $30K <$150K (EMPLOYEE) PC31.03(e5)',
#        'ILLEGAL DUMPING >OR EQ 500LBS<1000LBS >OR EQ 100CFT<200CFT HSC 365.012 (f)(1)',
#        'INHALANT PARAPHERNALIA USES OR POSS',
#        'THEFT OF PROP (ATT) <$1500 2+ CONV ENH (NOT BY EMP)',
#        'THEFT OF PROP <$50 W/PREV CONV ENH -SHOPLIFT -  (NOT BY EMP',
#        'BMV (ENCLOSED RAIL CAR) - FORCED ENTRY',
#        'THEFT OF PROP > OR EQUAL $200K-OTHER THAN SHOPLIFT',
#        'LEWD/IMMORAL/INDECENT CONDUCT',
#        'INSURANCE FRAUD W/INT TO DEFRAUD/DECEIVE',
#        'RESIST ARREST SEARCH OR TRANSPORT DEADLY WEAPON',
#        'SALE ALCOHOLIC BEVERAGE DURING PROHIBITED HOURS',
#        'DISORDERLY CONDUCT', 'MANSLAUGHTER',
#        'THEFT OF PROP > OR EQUAL $30K <$150K (NOT SHOPLIFT) PC31.03(e5)',
#        'THEFT OF PROP (ATT) > OR EQUAL $2,500 BUT <$30K (NOT EMP',
#        'ASSAULT (AGG) FAM VIO DEADLY WEAPON- NO SBI',
#        'ARSON -STORAGE - INHABITED',
#        'TRAF VIO -LICENSE CARRIED/EXHIBITED ON DEMAND 3RD',
#        'INTOX MANSLAUGHTER', 'POSS CONT SUB PEN GRP 4 <28G',
#        'POSS OF DANGEROUS DRUG', 'UNLAWFUL CARRY WEAPON/WEAPONS FREE ZONE',
#        'CRUELTY TO NON-LIVESTOCK ANIMALS: FAILURE TO PROVIDE FOR',
#        'THEFT OF PROP (ATT) > OR EQUAL $20K<$100K ENH (NOT EMP)',
#        'TERRORISTIC THREAT AGAINST PUBLIC SERVANT',
#        'ONLINE HARRASSMENT-NAME/PERSONA TO CREATE PAGE',
#        'LICENSE REQUIRED TO BREW/SALE BEER',
#        'ILLEGAL DUMPING COMM WGT/BARREL OR DRUM',
#        'GRAFFITI PECUNIARY LOSS <$20K',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $750 < $2500',
#        'ASSAULT -ELD OR DISABLED VIC -OFFENSIVE CONTACT',
#        'THEFT OF MATERIAL (ATT) 50% ALUM/BRNZE/COPPER <20K ENH',
#        'UCR - BMV-',
#        'THEFT OF PROP <$2,500 2+PREV CONV (SHOPLFT-NOT EMP) PC31.03(e4D)',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $1,500<$20K',
#        'THEFT ORG RETAIL -(BY EMP) >$1500<$20,000',
#        'CAPITAL MURDER WHILE REMUNERATION',
#        'POSS CONT SUB PEN GRP 3 < 28G *DRUG FREE ZONE*',
#        'TRAF VIO -FAIL TO COMPLY W/FINAN STATEMENT REQUIRES',
#        'BMV - PRELIMINARY INVESTIGATION',
#        'FRAUD USE/POSS IDENT INFO # ITEMS 10<50 ELDER',
#        'ILLEGAL DUMPING >1000 LBS OR > 200 CFT HSC 365.012(g)(1)',
#        'THEFT OF PROP (ATT) > OR EQUAL $1,500 BUT <$20K (BY EMP',
#        'KEEPING A GAMBLING PLACE', 'CRIMINAL TRESPASS AFFIDAVIT',
#        'THEFT OF PROP > OR EQUAL $2500 BUT <$30K ENH -SHOPLIFT-(NOT EMP',
#        'THEFT OF PROP > OR EQUAL $200K (BY EMPLOYEE)',
#        'THEFT OF PROP (ATT) > OR EQUAL  $1500 BUT <$20K ENH (BY EMP)',
#        'THEFT OF FIREARM (ATT', 'CRIM MISCHIEF > OR EQUAL $30K < $150K',
#        'TRAF VIO -DISPLAY FICTITIOUS LICENSE PLATE',
#        'PERMIT REQUIRED IN WET AREA',
#        'THEFT OF PROP $100 BUT <$750 ENH (BY EMPLOYEE)',
#        'POSS CONT SUB PEN GRP 1 > OR EQUAL 4G<200G',
#        'THEFT ORG RETAIL -(NOT EMP)> $2500<$30,000',
#        'THEFT OF ANIMAL CATTLE/HORSE/EXOTIC LIVESTOCK <$100K',
#        'TERRORISTIC THREAT CAUSES PECUNIARY LOSS OF >$1500',
#        'FRAUD TRANSFER OF MOTOR VEH <$20K',
#        'VIO BOND/PROTECTIVE ORDER ASSAULT/STALKING',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $500 < $1500',
#        'THEFT OF PROP <$2500 2+ CONV ENH  - NOT SHOPLIFT',
#        'PUBLIC INTOXICATION: MINOR 3RD ENH',
#        'TAMPER W/CONSUMER PRODUCT  NO INJUR',
#        'GRAFFITI PECUNIARY LOSS  >OR EQUAL $100 <$750 PC28.08(b2)',
#        'THEFT OF PROP <$1,500  2/MORE PREV CONV (BY EMP)',
#        'THEFT OF SERVICE (ATT) > OR EQUAL $20 BUT <$500',
#        'THEFT OF PROP > OR EQUAL $100 <$750 ENH (SHOPLIFT-NOT EMP) PC31.03(f)',
#        'POSS CONT SUB PEN GRP 3 > OR EQUAL  28G<200G',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $50 BUT <$500-(BY EMP',
#        'ARSON -(W BODILY INJURY OR DEATH)-OTH COMM-INHABITED',
#        'LICENSE AND DESIGNATED OPERATOR REQUIRED',
#        'UNLAWFUL CARRY HANDGUN LIC HOLDER',
#        'TRAF VIO - DRIVER LICENSE/ID FALSE',
#        'THEFT OF SERVICE > OR EQUAL $100 <$750 PC31.04(e2)',
#        'DELIVERY MARIJUANA >1/4 OZ< OR EQUAL 5LBS *DRUG FREE ZONE*',
#        'THEFT OF PROP (ATT) > OR EQUAL $750 BUT <$2,500 (NOT EMP)',
#        'THEFT OF PROP > OR EQUAL $100 <$750 (EMPLOYEE) PC31.03(e2A)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $750 BUT <$2,500-(BY EMP',
#        'THEFT OF PROP (ATT) > OR EQUAL $500 BUT <$1,500 (NOT EMP)',
#        'CRIM MISCHIEF >OR EQUAL $300K',
#        'THEFT OF PROP <$50 W/PREV CONVIC -SHOPLIFT-(NOT BY EMP)',
#        'HOAX BOMBS', 'ARSON -COMMUNITY/PUBLIC - UNINHABITED',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $20K<$100K - (NOT  EMP',
#        'FLEEING POLICE OFFICER IMMINENT DANGER SBI',
#        'THEFT OF PROP $500 BUT <$1500 ENH (BY EMPLOYEE)',
#        'THEFT OF PROP <$50 ENH -NOT SHOPLIFT',
#        'ASSAULT (AGG) -OF SECURITY OFF - SERIOUS BODILY INJURY',
#        'THEFT OF PROP > OR EQUAL $300K (BY EMPLOYEE)',
#        'ONLINE HARRASSMENT-EMAIL/MESSAGE W/IDENT INFOR',
#        'THEFT OF PROP <$2,500 2+CONV ENH (SHOPLIFT-NOT EMP) PC31.03(f)',
#        'ILLUMINATING AN AIRCRAFT W/LASER POINTER IMPAIR OPERATOR',
#        'UNLAWFUL POSS METAL OR BODY ARMOR BY FELON', 'OFFICIAL OPPRESSION',
#        'MAN DEL CONT SUB PEN GRP 2 > OR EQUAL 1G<4G',
#        'POSS CONT SUB PEN GRP 2 > OR EQUAL  1G<4G',
#        'TERRORISTIC THREAT IMPAIR PUBLIC/GOV SERVICE',
#        'ENGAGING IN ORGANIZED CRIMINAL ACTIVITY FS',
#        'THEFT ORG RETAIL - (NOT EMP) EQUAL $50<$500',
#        'DELIVERY MARIJUANA >1/4 OZ< OR EQUAL 5LBS', 'ESCAPE FROM CUSTODY',
#        'INSURANCE FRAUD > OR EQUAL $100<$750',
#        'CRIM MISCHIEF TRANS/COMM EQUIP/DEV <$100,000',
#        'UNLAWFUL POSS FIREARM BY FELON WEAPONS FREE ZONE',
#        'UNLAWFUL CARRYING WEAPON ON ALCOHOL PREMISES',
#        'ILLEGAL DUMPING W/PREV CONV (FELONY)',
#        'TRAF VIO -DUTY ON STRIKE FIX/HWY LANDSCAPE <  $200',
#        'ASSAULT -PUB SERV (PEACE OFFICER/JUDGE)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $100 BUT <$750-(BY EMP',
#        'TERRORISTIC THREAT OF FAMILY/HOUSEHOLD',
#        'INTERFERE W/POLICE SERV ANIMAL DEPRIVE HANDLING',
#        'THEFT OF ANIMAL CATTLE/HORSE/EXOTIC (ATT) <$100K',
#        'THEFT ORG RETAIL - (BY EMP) EQUAL $50<$500',
#        'TRAF VIO -DRIVING W VIO  FIN RESP ACCIDENT SBI/DEATH',
#        'ASSAULT (AGG) -PUBLIC SERVANT - (AGG, NON LAW ENF)',
#        'INTOX ASSAULT SERIOUS BOD INJ TO PEACE OFC/FIREFIGHT/EMS',
#        'BRIBERY', 'FRAUD DELIVERS PRESCRIPTION FORMS SCHEDULE LLL,LV,V',
#        'THEFT OF PROP > OR EQUAL $100 <$750 ENH (NOT SHOPLIFT) PC31.03(f)',
#        'HARASSMENT BY PERSON IN CORRECTIONAL/DETENTION',
#        'THEFT OF PROP <$100 W/PREV CONV ENH -SHOPLIFT -  (NOT BY EMP',
#        'SEX OFFENDERS DUTY TO REGISTER LIFE/90 DAY (CCCP 62.102(B)(3))',
#        'FRAUD TRANSFER OF MOTOR VEH > OR EQUAL $20K',
#        'COMPUTER SECURITY BREACH < AGGREGATE $100',
#        'MAN DEL CONT SUB PEN GRP 1 <1G *DRUG FREE ZONE*',
#        'MANIFESTING FOR SELLING DRUGS', 'THEFT OF SERVICE (ATT) < $100',
#        'KIDNAPPING', 'SEX OFFENDERS DUTY TO REGISTER 10YRS',
#        'MAN DEL CONT SUB PEN GRP 3/4 > OR EQUAL 200G<400G',
#        'TAKE WEAPON FROM AN OFFICER (MACE/TASER)',
#        'THEFT OF PROP > OR EQUAL $20K<$100K SHOPLIFT (NOT BY EMP)',
#        'BIGAMY', 'DECEPTIVE TRADE PRACTICE',
#        'OBSCENE PROMOTE/PRODUCE/DIRECT',
#        'ONLINE IMPERSONATION-EMAIL/MESSAGE W/IDENT INFOR',
#        'MAN DEL CONT SUB PEN GRP 1 > OR EQUAL 1G<4G',
#        'COMPUTER SECURITY BREACH',
#        'CRIM MISCHIEF >OR EQUAL $150K BUT <$300K',
#        'TRAF VIO -RECKLESS DRIVING', 'POSS OF ALCOHOL BY A MINOR',
#        'UNLAWFUL CARRYING WEAPON PROHIBITED PLACES',
#        'THEFT ORG RETAIL -(NOT EMP)> OR EQUAL $30K<$150',
#        'ARSON -(W BODILY INJURY OR DEATH)-ALL OTH STRUCT - INHABIT',
#        'MAN DEL CONT SUB PEN GRP 1A > OR EQUAL 20<80AU',
#        'ENGAGING IN ORGANIZED CRIMINAL ACTIVITY F3',
#        'CRUELTY TO NON-LIVESTOCK ANIMALS FAILURE TO PROVIDE FOR',
#        'THEFT OF SERVICE > OR EQUAL $2,500 <$30K PC31.04(e4)',
#        'THEFT OF PROP (ATT) > OR EQUAL $20K<$100K (NOT EMP)',
#        'HINDER APPREHENSION OR PROSECUTION KNOWN FELON',
#        'TAMPER W/IDENTIFICATION NUMBERS PERSONAL PROBERTY',
#        'THEFT OF PROP > OR EQUAL $1500 BUT <$20K ENH -SHOPLIFT-(NOT EMP',
#        'THEFT OF ANIMAL CATTLE/HORSE/EXOTIC LIVESTOCK <$150K',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $50 < $500',
#        'STALKING W/PREV CONVICTION', 'CRIM MISCHIEF > OR EQUAL $200K',
#        'THEFT OF PROP (ATT) > OR EQUAL $50 BUT <$500 (BY EMP)',
#        'THEFT OF PROP (ATT) > OR EQUAL $500 BUT <$1,500 (BY EMP)',
#        'THEFT OF PROP (ATT) $50 BUT <$500 ENH (NOT EMPLOYEE)',
#        'THEFT OF PROP <$100 ENH (NOT SHOPLIFT) PC31.03(f)',
#        'THEFT OF MATERIAL (ATT) ALUM/BRNZE/COPPER <$20K PC31.03(e4F)',
#        'UCR - MANSLAUGHTER (0120) (FOR UCR PURPOSES ONLY)',
#        'ABUSIVE/SILENT CALL/ELECTR COMM TO 911 SERVICE  PC 42.061(d)',
#        'DISRUPT MEETING OR PROCESSION',
#        'MAN DEL CONT SUB PEN GRP 2 or 2-A > OR EQUAL 4G<400G',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $1500 < $20K',
#        'POSS CONT SUB PEN GRP 2 < 1G *DRUG FREE ZONE*',
#        'VIO PROTECT ORDER BIAS/PREJUDICE',
#        'THEFT OF PROP <$2500  2/MORE PREV CONV (BY EMP)',
#        'ROBBERY OF INDIVIDUAL - PRELIMINARY INVESTIGATION',
#        'ASSAULT (AGG) -BY PUBLIC SERVANT (AGG)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT > $30K < $150K PC32.32(c5)',
#        'UCR - MURDER',
#        'THEFT OF PROP > OR EQUAL $1500 BUT <$20K ENH (BY EMPLOYEE)',
#        'THEFT OF PROP > OR EQUAL $150K <$300K (NOT SHOPLIFT) PC31.03(e6A)',
#        'THEFT OF PROP <$100 W/PREV CONV ENH (NOT SHOPLIFT) PC31.03(f)',
#        'THEFT TAMPER MULTICHANNEL VIDEO REMUNERATION',
#        'REPEATED VIOL.OF CERTAIN C.O.OR COND. OR BOND IN FAM. VIOL',
#        'THEFT FROM PERSON-PURSE SNATCH ENHANCE',
#        'KIDNAPPING (AGG) -FOR RANSOM/REWARD',
#        'INSURANCE FRAUD > OR EQUAL $30K<$150K',
#        'POSS CONT SUB PEN GRP 4 > OR EQUAL 28G *DRUG FREE ZONE*',
#        'THEFT OF PROP > OR EQUAL $300K-OTHER THAN SHOPLIFT',
#        'ILLUMINATING AN AIRCRAFT W/LASER POINTER',
#        'TRAF VIO -DISOBEY WARN SIGN/BARRICADE OVER ROAD',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2500 BUT<$30K ENH(NOT EMP)',
#        'UNAUTHORIZED REPRODUCTION OF TEXAS TEMP TAG',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $20<$500 ELDERLY',
#        'ARSON -(W BODILY INJURY OR DEATH)-OTH RESDE-UNINHABITED',
#        'THEFT OF PROP (ATT) $500 BUT <$1500 ENH (BY EMPLOYEE)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $150K<$300K -(BY EMP)',
#        'STAMPS ON DISTILLED SPIRITS CONTAINER',
#        'EVADING ARREST DETENTION W/PREV CONVICTION PC38.04(b1)',
#        'THEFT OF PROP (ATT) > OR EQUAL $100 BUT <$750 (BY EMP)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $20K<$100K  - (BY EMP)',
#        'UCR - BMV- STOLEN PROP/DAMAGE COLUMN/IGNITION -TRUCK',
#        'THEFT OF PROP (ATT) > OR EQUAL $100 <$750 (NOT EMP) PC31.03(e2A)',
#        'TAMPER W/GOVT RECORD-INSURANCE DOCUMENTS',
#        'THEFT OF PROP (ATT) > OR EQUAL $150K<$300K (NOT EMP)',
#        'FRAUD POSS CS/PRESCRIPTION SCH III, IV',
#        'FRAUD POSS PRESRCIPTION FORM SCHEDULE IL OR LII CONT SUB',
#        'MAN DEL CONT SUB PEN GRP 1 > OR EQUAL 1G *DRUG FREE ZONE*',
#        'DRIVING UNDER INFLUENCE MINOR 3RD-ENH',
#        'DECEPTIVELY SIMILAR REGISTRATION INSIGNIA (MAN/SELL)',
#        'POSS CONT SUB PEN GRP 2-A < OR EQUAL 2 OZ',
#        'INSURANCE FRAUD > OR EQUAL $2500<$30K',
#        'CRIM MISCHIEF <$1500 HABITATION FA/EXPLOS', 'DOG FIGHTING -',
#        'LABELING UNAUTHORIZED RECORDING > 7 BUT <65 W/I 180D',
#        'UNLAWFUL RESTRAINT:EXPOSE TO SBI',
#        'POSS CONT SUB PEN GRP 1 >1G *DRUG FREE ZONE*',
#        'MAN DEL CONT SUB PEN GRP 2 or 2-A > OR EQUAL 1G<4G',
#        'THEFT OF PROP (AUTO ACC) $50 BUT <$500 ENH  -(BY EMP)',
#        'FRAUDULENT TRANSFER OF MOTOR VEHICLE <$30K',
#        'HOURS OF SALE OF BEER PROHIBITED',
#        'THEFT OF PROP (ATT) > OR EQUAL $750 <$2,500 (NOT EMP) PC31.03 (e3)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $200K - (NOT EMP)',
#        'MAN DEL CON SUB PEN GRP 1A <20 AU',
#        'ILLEGAL DUMPING COMM WGHT 5LBS < 200 LBS',
#        'SALVAGE VEHICLE NO RECORDS',
#        'POSS MARIJUANA >2OZ< OR EQUAL 4OZ *DRUG FREE ZONE*',
#        'MAN DEL CONT SUB PEN GRP 3/4 <28G',
#        'THEFT OF PROP (ATT) > OR EQUAL $30K<$150K (NOT EMP)',
#        'INTERFERE W/ CHILD CUSTODY -PRELIMINARY INVESTIGATION',
#        'THEFT OF PROP (ATT) > OR EQUAL $750 BUT <$2,500 (BY EMP)',
#        'THEFT ORG RETAIL - (NOT EMP) EQUAL $100<$750',
#        'POSSESSION AND USE OF VOLATILE CHEMICAL',
#        'TRAFFICKING OF PERSONS W/INTENT FORCED LABOR',
#        'COMPUTER SECURITY BREACH >OR EQUAL TO $750 BUT <$2500',
#        'FALSE REPORT REGARDING MISSING CHILD OR MISSING PERSON',
#        'POSS MARIJUANA >5LBS< OR EQUAL 50LBS',
#        'TAMPER W/GOVT RECORD W/INT MAKE GENUINE',
#        'ARSON -OTHER MOBILE PROPERTY', 'FAILURE TO REPORT FELONY',
#        'THEFT ORG RETAIL - (BY EMP) > OR EQUAL $20,000<$100,000',
#        'THEFT OF PROP > OR EQUAL $100K<$200K (BY EMPLOYEE)',
#        'TRADEMARK COUNTERFEITING > OR EQUAL TO $20 BUT < $500',
#        'COERCION OF PUBLIC SERVANT/VOTER THREAT OF FELONY',
#        'THEFT OF PROP (AUTO ACC) < $50-W/ 2+ CONV (NOT EMP)',
#        'THEFT OF PROP > OR EQUAL $750 <$2,500 ENH (SHOPLIFT-NOT EMP) PC31.03(f)',
#        'EXHIBITION OF FIREARMS (SCHOOL)',
#        'THEFT OF PROP <$100 W/PREV CONV (SHOPLIFT-NOT EMP) PC31.03(e2B)',
#        'THEFT ORG RETAIL -(BY EMP) >$2500<$30,000',
#        'THEFT OF PROP (ATT) <$50 (BY EMPLOYEE)',
#        'POSS W/INT TO PROMOTE CHILD PORNOGRAPHY',
#        'THEFT OF PROP (ATT) > OR EQUAL $2,500 <$30K (NOT EMP) PC31.03(e4A)',
#        'VIO BOND/PROTECTIVE ORDER 2+ PREV CONVICTIONS',
#        'THEFT OF SERVICE (ATT) > OR EQUAL $1,500 BUT <$20K',
#        'FRAUD EXPLOITATION OF CHILD/ELDERLY/DISABLED( PC 32.53(c))',
#        'DEADLY CONDUCT-PRELIMINARY INVESTIGATION',
#        'ILLEGAL DUMPING >5 LBS < 500 LBS OR >5 GAL <100 CFT HSC 365.012(e)',
#        'ASSAULT (AGG) -PUB SER (LAW ENF) - SER BOD INJ',
#        'POSS CONT SUB PEN GRP 4 > OR EQUAL 28G<200G',
#        'TAMPER FABRICATE PHY EVID/FAILS REPORT HUMAN REMAINS',
#        'THEFT OF SERVICE (ATT) > OR EQUAL $500 BUT <$1,500',
#        'FRAUD USE/POSS IDENTIFYING INFO-PRELIMINARY INVESTIGATION',
#        'THEFT OF SERVICE > OR EQUAL $20K BUT <$100K',
#        'ASSAULT -FAM VIO ELD OR DISABLED VIC -OFFENSIVE CONTACT',
#        'COMPUTER SECURITY BREACH >$300', 'SEIZED PROPERTY (NO OFFENSE)',
#        'UNAUTH OPERATION RECORDING DEVICE MOTION PICTURE THEATER',
#        'GRAFFITI REAL/PERSONAL PROP > OR EQUAL $750 <$30K PC28.08 (d2)',
#        'BURGLARY - PRELIMINARY INVESTIGATION',
#        'THEFT OF PROP > OR EQUAL $150K<$300K -SHOPLIFT  (NOT EMP)',
#        'THEFT OF PROP > OR EQUAL $2500 BUT <$30K ENH (BY EMPLOYEE)',
#        'MAN DEL CONT SUB PEN GRP 2 or 2-A < 1G *DRUG FREE ZONE*',
#        'ASSAULT (AGG) -PUB SERV (NON LAW ENF) - SER BODY INJURY',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $300K - (NOT EMP)',
#        'CRUELTY TO LIVESTK ANIM FAIL TO PROVIDE',
#        'THEFT OF PROP > OR EQUAL $30K<$150K ENH (BY EMPLOYEE)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT > $750 < $2,500 PC32.32(c3)',
#        'FRAUD DEL CS/PRESCRIPTION SCH II/SCRIPT FORM',
#        'ARSON -(W BODILY INJURY OR DEATH) -SINGLE RES UNINHAB',
#        'ASSAULT (AGG) -EMS PER PROVIDE SERVICE - SER BODY INJ',
#        'THEFT OF PROP <$100 ENH -NOT SHOPLIFT',
#        'CRIM MISCHIEF <$2500 LS/GAME ANIM FENCE',
#        'THEFT OF PROP (ATT) <$1,500  2+ PREV CONV (NOT EMP)',
#        'CAPITAL MURDER OF A PEACE OFFICER/ FIREFIGHTER',
#        'DECEPTIVE BUSINESS PRACTICE-CRIM NEG',
#        'THEFT OF PROP (AUTO ACC) >OR EQUAL $100 <$750 ENH (NOT EMP) PC31.03(f)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2,500 <$30K ENH (NOT EMP) PC31.03(f)',
#        'THEFT OF PROP (AUTO ACC) <$2,500 2+ PREV CONV (NOT  EMP)(P.C. 31.03 E4D)',
#        'THEFT OF PROP (ATT) $100 BUT <$750 ENH (NOT EMPLOYEE)',
#        'THEFT OF PROP <$2,500 2+PREV CONV (NOT SHOPLIFT) PC31.03 (e4D)',
#        'FALSE ID AS POLICE OFFICER',
#        'ASSAULT -OF CORRECTIONAL OFFICER - BODILY INJURY ONLY',
#        'THEFT OF PROP (ATT) <$1500 2+ CONV ENH (BY EMP)',
#        'PURCHASE FURNISH ALCOHOL TO A MINOR',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $750 <$2,500 ENH (NOT EMP) PC 31.03(f)',
#        'THEFT OF MATERIAL ALUM/BRNZE/COPPER <$20K ENH PC31.03(f)',
#        'THEFT OF PROP (ATT) > OR EQUAL $1500 BUT <$20K ENH(NOT EMP',
#        'THEFT OF PROP (ATT) <$2500 2+ CONV ENH (NOT BY EMP)',
#        'TRAF VIO -RACING ON HIGHWAY WITH PREV CONV OR W/DWI',
#        'OPEN BUILDING (NO OFFENSE)',
#        'TRADEMARK COUNTERFEITING > OR EQUAL TO $2,500 BUT < $30K',
#        'MAN DEL CONT SUB PEN GRP 3/4 > OR EQUAL 28G<200G',
#        'THEFT - PRELIMINARY INVESTIGATION',
#        'THEFT OF PROP <$100-OTH THAN SHOPLIFT-W/PREV CONV',
#        'ENGAGING IN ORGANIZED CRIMINAL ACTIVITY F2',
#        'THEFT OF PROP (ATT) > OR EQUAL $100 <$750 (EMP) PC31.03(e2A)',
#        'ABANDON/ENDANGER CHILD WITH INTENT TO RETURN',
#        'FRAUD DESTROY REMOVAL CONCEALMENT WRITING ENH',
#        'GRAFFITI PECUNIARY LOSS <$100K',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $150K<$300K',
#        'TAMPER FABRIC. PHYSICAL EVID. ALTER,DESTROY CONCEAL HUMAN CORPSE',
#        'FORGERY- PREMINARY INVESTIGATION',
#        'POSS CONT SUB NOT IN PEN GRP *DRUG FREE ZONE*',
#        'THEFT OF PROP (AUTO ACC) $500 BUT <$1500 ENH  -(BY EMP)',
#        'THEFT OF PROP (AUTO ACC) <$50  - (BY EMPLOYEE)',
#        'THEFT OF MATERIAL (ATT) ALUM/BRNZE/COPPER <$20K ENH',
#        'POSS MARIJUANA >50LBS< OR EQUAL 2,000LBS',
#        'PLACEMENT OF SERIAL NUMBERS WITH INTENT TO CHANGE IDENTITY',
#        'THEFT OF PROP (ATT) > OR EQUAL $100 <$750 ENH (NOT EMP) PC31.03(f)',
#        'TRADEMARK COUNTERFEITING <$100',
#        'CONSUME/PERMIT A/B ON LIC PREMISES PROH HOURS',
#        'KIDNAPPING (AGG) -TERRORIZE PERSON OR 3RD PARTY',
#        'POSS CONT SUB NOT IN PEN GRP',
#        'FAIL TO ID -REFUSES TO PROVIDE INFO',
#        'MAN DEL CONT SUB PEN GRP 2 < 1G',
#        'OBSTRUCTION OR RETALIATION AGAINST JUROR',
#        'INVALIDATION OF STAMP LOCAL DISTRIBUTOR',
#        'POSS CONT SUB PEN GRP 1A <20AU',
#        'ABANDON/ENDANGER CHILD CRIMINAL NEGLIGENCE',
#        'THEFT ORG RETAIL -(NOT EMP)> OR EQUAL $20K<$100',
#        'SECURE EXECUTION DOC BY DECEPTION > OR EQUAL TO $1,500 BUT <$20K',
#        'AIRPLANE CRASH (NO INJURIES OR DEATH INVOLVED)',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $100<$750',
#        'CRIM MISCHIEF TRANS/COMM EQUIP/DEV <$150,000',
#        'UNREGISTERED CLUB - PROHIBITED ACTIVITIES',
#        'POSS CONT SUB PEN GRP 3 > OR EQUAL 1G *DRUG FREE ZONE*',
#        'CRIM MISCHIEF -PRELIMINARY INVESTIGATION',
#        'THEFT OF SERVICE > $200K',
#        'ABANDON/ENDANGER CHILD W/OUT INTENT TO RETUR',
#        'TERRORISTIC THREAT REACTION EMERGENCY AGENCY',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $100 < $750',
#        'UNAUTHORIZED USE OF MOTOR VEH - PRELIMINARY INVEST',
#        'TRAFFICKING OF PERSONS ENGAGE CONDUCT/SEXUAL/BENEFIT',
#        'DISRUPTIVE ACTIVITIES (SCHOOL',
#        'CREDIT CARD OR DEBIT CARD ABUSE - PRELIMINARY INVESTIGATION',
#        'THEFT OF PROP (AUTO ACC) $100 BUT <$750 ENH  -(BY EMP)',
#        'THEFT OF CATTLE/HORSE/EXOTIC LIVESTOCK <$150K PC31.03(e5A)',
#        'OTHER OFFENSE - MISDEMEANOR', 'TRAF VIO -RACING ON HIGHWAY',
#        'THEFT OF PROP > OR EQUAL $300K (EMPLOYEE) PC31.03(e7)',
#        'TRADEMARK COUNTERFEITING > OR EQUAL TO $20K BUT < $100K',
#        'THEFT OF PROP > OR EQUAL $2,500 <$30K ENH (NOT SHOPLIFT) PC31.03(f)',
#        'ALARM INCIDENT REPORT (WITH OFFENSE)',
#        'THEFT OF PROP > OR EQUAL $30K<$150K ENH- NOT SHOPLIFT', 'PERJURY',
#        'ROBBERY (AGG) OF INDIVIDUAL, PRELIMINARY INVESTIGATION',
#        'HARASSMENT -PRELIMINARY INVESTIGATION',
#        'THEFT OF PROP <$2,500 2+CONV ENH (NOT SHOPLIFT) PC31.03(f)',
#        'SECURE EXECUTION DOC DECEPTION > OR EQUAL TO $150K BUT < $300K',
#        'THEFT OF PROP (ATT) <$100 ENH (NOT EMPLOYEE)',
#        'WARRANT DALLAS PD (OTHERS)',
#        'ILLEGAL DUMPING LT LIT/WASTE <500LBS OR <100 CFT HSC 365.012(d-1)',
#        'CRIM MISCHIEF < $2,500 HABITATION W/FA/EXPLOS',
#        'THEFT OF CARGO > OR EQUAL $10K < $100K (NOT EMP) PC31.18(c2)',
#        'ABUSE OF CORPSE',
#        'THEFT OF PROP (ATT) <$2,500  2+ PREV CONV (NOT EMP)',
#        'THEFT ORG RETAIL - (BY EMP) > OR EQUAL $150,000<$300,000',
#        'OBSCENE PROMOTE/PRODUCE/DIRECT W/DEVIANT SEX ACT',
#        'COMPUTER SECURITY BREACH >OR EQUAL TO $100 BUT <$750',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2,500 <$30K(EMP) PC31.03(e4A)',
#        'THEFT OF PROP > OR EQUAL $30K<$150K SHOPLIFT (NOT BY EMP)',
#        'THEFT OF PROP (ATT) <$50 ENH (NOT EMPLOYEE)', 'INDECENT EXPOSURE',
#        'CRIMINAL TRESPASS - RESID LAND W/IN 100FT PROTECTED WATER',
#        'LOCATION OF SEXUALLY ORIENTED BUSINESSES',
#        'THEFT OF PROP (AUTO ACC) <$1,500 2+ PREV CONV (NOT  EMP)(P.C. 31.03 E4D)',
#        'ARSON -(W BODILY INJURY OR DEATH) -COM/PUBLIC - UNINHAB',
#        'FRAUDULENT TRANSFER OF M V >OR EQUAL TO $150K <$300K',
#        'INSURANCE FRAUD  RISKING BODILY INJ/DEATH',
#        'THEFT OF PROP > OR EQUAL $20 BUT <$500 BY CHECK ENH',
#        'PERJURY (AGG',
#        'THEFT OF CARGO > OR EQUAL $1,500 < $10K (EMP) PC31.18(c1)',
#        'WARRANT DALLAS PD (THEFT OTHER)',
#        'THEFT OF PROP (ATT) > OR EQUAL $200K (NOT EMPLOYEE)',
#        'CRUELTY TO LIVESTK ANIM TORTURE',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $2500 BUT<$30K ENH(BY EMP)',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT > $300K PC32.32(c7)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $150K<$300K -(NOT EMP)',
#        'THEFT OF PROP (ATT) > OR EQUAL $30K <$150K (EMP) PC31.03(e5)',
#        'POSS CONT SUB PEN GRP 4 > OR EQUAL 200G<400G',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT $200K',
#        'TERRORISTIC THREAT AGAINST PUB SERV (PEACE OFFICER /JUDGE',
#        'STALKING- PRELIMINARY INVESTIGATION',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $2,500<$30K',
#        'THEFT OF CATTLE/HORSE/EXOTIC LIVESTOCK (ATT) <$150K PC31.03(e5A)',
#        'THEFT OF SERVICE > OR EQUAL $30K <$150K PC31.04(e5)',
#        'THEFT OF PROP (ATT) > OR EQUAL $150K <$300K (EMP) PC31.03(e6A)',
#        'THEFT OF PROP <$100 ENH (SHOPLIFT-NOT EMP) PC31.03(f)',
#        'MONEY LAUNDERING > $300K PC34.02(e4)',
#        'INSURANCE FRAUD > OR EQUAL $750<$2500',
#        'ARSON -(W BODILY INJURY OR DEATH) -ALL OTH STRUCT-UNINHAB',
#        'ASSAULT (AGG) FAM VIO SBI',
#        'SECURE EXECUTION DOC DECEPTION > OR EQUAL TO $200K',
#        'ENGAGING IN ORGANIZED CRIMINAL ACTIVITY MA',
#        'FALSE STATEMENT FOR PROPERTY/CREDIT < $100',
#        'THEFT OF PROP <$50 ENH (BY EMPLOYEE)',
#        'WARRANT DALLAS PD (ASSAULT - FV)',
#        'POSS CONT SUB PEN GRP 4 > OR EQUAL 400G',
#        'TRAF VIO -OP OF MOTOR VEH REG SUSPENDED',
#        'PROHIBITED WEAPON/WEAPONS FREE ZONE',
#        'BMV <$1,500 2/MORE PREV CONV- (BY EMPLOYEE', 'TAMPER W/WITNESS',
#        'THEFT OF PROP (ATT) > OR EQUAL $30K<$150K ENH (NOT EMP)',
#        'ARSON -(W BODILY INJURY OR DEATH) -OTH COMM - UNINHAB',
#        'FRAUD DEL CS/PRESCRIPTION SCH III,IV,V',
#        'THEFT OF PROP (ATT) > OR EQUAL $200K (BY EMPLOYEE)',
#        'ASSAULT (AGG) FAM VIO IMPED BREATH/CIRC LOSS OF CON',
#        'POSS MARIJUANA >5LBS *DRUG FREE ZONE*',
#        'HARASSMENT W/PREV CONVICTION',
#        'ENGAGING IN ORGANIZED CRIMINAL ACTIVITY F1', 'BOATING WHILE INTOX',
#        'ARSON -INDUSTRIAL/MANUFACTURING - UNINHABITED',
#        'TRAF VIO -RACING ON HIGHWAY CAUSING BODILY INJURY',
#        'THEFT OF SERVICE > OR EQUAL $30K BUT <$150K',
#        'INTERFERE W/EMERGENCY CALL',
#        'POSS CONT SUB PEN GRP 2 > OR EQUAL 1G *DRUG FREE ZONE*',
#        'GRAFFITI PECUNIARY LOSS > OR EQUAL $2500 <$30K PC28.08(b4)',
#        'UCR - BMV- STOLEN PROP/DAMAGE COLUMN/IGNITION -OTHER',
#        'THEFT OF SERVICE > OR EQUAL $100K BUT <$200K',
#        'ASSAULT -GOVT CONTR OR EMP VIC - BODILY INJURY ONLY',
#        'INJURY CHILD/ELDERLY/DISABLED - PRELIMINARY INVESTIGATION',
#        'MAN DEL CONT SUB PEN GRP 2 > OR EQUAL 1G *DRUG FREE ZONE*',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $30K<$150K  - (BY EMP)',
#        'MISAPP FIDUC/FINAN PROP > OR EQUAL $30K<$150K',
#        'UNLAWFUL CARRY HANDGUN LIC HOLDER ALCH PREM/CORR FAC',
#        'FORGING OR ALTERING PRESCRIPTION ENH',
#        'MAN DEL CONT SUB PEN GRP 2 > OR EQUAL 400G',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $1500 BUT<$20K ENH(BY EMP)',
#        'CRIMINAL TRESPASS- AGRICULTURAL LAND W/IN 100FT OF BOUNDARY',
#        'THEFT OF TRADE SECRETS',
#        'CRIM MISCHIEF > OR EQUAL $750 < $30K DESTROY SCHOOL',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $20K<$100K ENH - (NOT EMP',
#        'THEFT OF PROP > OR EQUAL $150K <$300K ENH (NOT SHOPLIFT) PC31.03(f)',
#        'OTHER OFFENSE - FELONY',
#        'THEFT OF PROP <$100-OTH THAN SHOPLIFT W/PREV CONVIC ENH',
#        'ASSAULT -FAM VIO ELD OR DISABLED VIC -BODILY INJURY ONLY',
#        'TRADEMARK COUNTERFEITING > OR EQUAL TO $750 < $2500 PC32.23 (e3)',
#        'CRIM MISCHIEF > OR EQUAL $150K < $300K',
#        'ILLEGAL DUMPING IN CLOSED BARREL OR DRUM HSC 365.012(g)(3)',
#        'WARRANT DALLAS PD (TRAFFIC VIOLATION - OTHER THAN ALIAS OR CAPIAS)',
#        'WARRANT DALLAS PD (FORGE & COUNTERFEIT)',
#        'TERRORISTIC THREAT -PRELIMINARY INVESTIGATION',
#        'ROBBERY (AGG) OF BUSINESS, PRELIMINARY INVESTIGATION',
#        'IMPROPER PHOTOGRAPHY OR VISUAL RECORDING',
#        'DELIVERY MARIJUANA < OR EQUAL 1/4 OZ REMUNERATION',
#        'PROSTITUTION (SELLER)',
#        'GRAFFITI PECUNIARY LOSS > OR EQUAL $750 <$2500 PC28.08(b3)',
#        'UCR - BMV (NO CODE)',
#        'TRAF VIO -DISPLAY FICTITIOUS MOTOR VEH REGISTRATION',
#        'ESCAPE CAUSE BODILY INJURY',
#        'WARRANT DALLAS PD (PUBLIC INTOXICATION)', 'UCR- UUMV-NO CODE',
#        'HOMICIDE (POLICE SHOOTING)', 'WARRANT DALLAS PD (MURDER)',
#        'THEFT OF PROP > OR EQUAL $30K <$150K (SHOPLIFT-NOT EMP) PC31.03(e5)',
#        'THEFT OF SERVICE -PRELIMINARY INVESTIGATION',
#        'MANIFESTING FOR PROSTITUTION (SELLER)', 'PUBLIC LEWDNESS',
#        'NO CODE', 'MAN DEL CONT SUB PEN GRP 2 or 2-A < 1G',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $750 <$2,500 (EMP) PC31.03(e3)',
#        'MANIFESTING FOR PROSTITUTION (BUYER)',
#        'MAN DEL CONT SUB PEN GRP 3/4 < 28G *DRUG FREE ZONE*',
#        'CRIM MISCHIEF > OR EQUAL $300K',
#        'FRAUDULENT TRANSFER OF M V > OR EQUAL $30K <$150K PC32.34(f2)',
#        'POSS CONT SUB PEN GRP 2-A > 2 OZ < OR EQUAL 4 OZ',
#        'UNAUTHORIZED USE OF MOTOR VEH -(TEST DRIVE',
#        'ASSAULT -ELD OR DISABLED VIC -THREATS',
#        'DWI W/PREV INTOXICATED MANSLAUGHTER CONVICTION',
#        'MAN DEL CONT SUB PEN GRP 3/4 > OR EQUAL  400G',
#        'ABANDON/ENDANGER CHILD IMMINENT DANGER B.INJURY',
#        'WARRANT DALLAS PD (AGG ASSAULT - FV)',
#        'CRIM MISCHIEF IMP/INT PUB SERVICE < $30K',
#        'THEFT OF PROP > OR EQUAL $2500 <$30K ENH (SHOPLIFT-NOT EMP) PC31.03f)',
#        'INTOX MANSLAUGHTERR CAUSE DEATH PEACE OFC/FIRE/EMS',
#        'FRAUD POSS CS/PRESRCIPTION SCH IV OR V',
#        'KIDNAPPING � PRELIMINARY INVESTIGATION',
#        'WARRANT DALLAS PD (CRIMINAL TRESPASS)',
#        'MANUFACTURE OF DANGEROUS DRUG',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $30K <$150K (NOT EMP) PC31.03(e5)',
#        'HOMICIDE', 'WARRANT DALLAS PD (NARCOTICS & DRUGS)',
#        'ROBBERY OF BUSINESS - PRELIMINARY INVESTIGATION',
#        'VIO PROTECTIVE ORDER ISSUED BASED ON SEX OFF',
#        'THEFT OF PROP > OR EQUAL $150K<$300K ENH-NOT SHOPLIFT',
#        'POSSSESS, MANUFACTOR OR DISTRIBUTE RETAIL THEFT  INSTRUMENT',
#        'ASSAULT (AGG) -GOVERN CONTRACTOR OR EMP VIC - SBI',
#        'THEFT ORG RETAIL > OR EQUAL $2,500 <$30K (EMP) PC31.16 (c4)',
#        'THEFT OF PROP (AUTO ACC) > OR EQUAL $150K <$300K (NOT EMP) PC 31.03(e6A)',
#        'TRAFFICKING OF PERSONS (PROSTITUTION/FORCED LABOR) <18 FOR',
#        'TRAF VIO -MAKE/POSS CFT INSP RPT/INS DOC INTD HARM/DEFRAUD',
#        'ASSAULT ON PUBLIC SERVANT (AGG) � PRELIMINARY INVESTIGATION',
#        'WARRANT DALLAS PD (VANDALISM & CRIMINAL MISCHIEF)',
#        'WARRANT DALLAS PD (ROBBERY - INDIVIDUAL)',
#        'THEFT OF PROP > OR EQUAL $300K (NOT SHOPLIFT) PC 31.03(e7)',
#        'WARRANT DALLAS PD (AGG ASSAULT - NFV)',
#        'DELIVERY OR OFFER OF DELIVERY OF DANGEROUS DRUG',
#        'MISAPP FIDUCIARY/FINANCE PROPERTY ELDERLY',
#        'TAKE WEAPON FROM AN OFFICER (GUN OR BATON)'], dtype=object)

# %%
print(df['Victim Type'].unique())
# Out:
# ['Individual' 'Business' nan 'Society/Public' 'Government' 'Person'
#  'Financial Institutio' 'Other' 'Law Enforcement Offi'
#  'Religious Organizati' 'Unknown']

# %%
byIncidentType = df.groupby('Type of Incident')

# %%
byIncidentType['Count'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-4c8c589d7256> in <module>()
# ----> 1 byIncidentType['Count'].describe()
#
# ~\Anaconda2\envs\rstudio\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: Count'
