# %% [markdown]
# <h1><center>DALLAS CRIME DATA</center></h1>
# <h2><center>MSDS 7331 Project</center></h2>
#
# <h4><center>Team Members</center></h4>
#
#               Yejur Singh Kunwar               Bin Yu                     Vivek Viswanathan              Kevin Mendosa
#               Dallas, TX                       Dallas, TX                 Dallas, TX                     Irvine, CA

# %% [markdown]
# ***### EDIT IN OWN WORDS ###***
#
# DESCRIPTION OF DATA
#
# The dataset represents the Dallas Police Public Data - RMS Incidents from June 1, 2014 to September 7, 2018. This police report information allows the citizens of Dallas to access accurate information in a timely manner. Crime classifications are based on information supplied to the Dallas Police Department.   This information is preliminary and could be reclassified later based on further investigation.
#
# To ensure that privacy concerns are protected, and legal standards are met, report data is "filtered" prior to being made available to the public. Among the exclusions are:
#
# - Sexually oriented offenses
#
# - Offenses where juveniles or children (individuals under 17 years of age) are the victim or suspect
#
# - Listing of property items that are considered evidence
#
# - Social Service Referral offenses
#
# - Identifying vehicle information in certain offenses
#
# - From June 1, 2014 to September 7, 2018

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ## Business Understanding
#
# ### Background
#
# The dataset represents the Dallas Police Public Data - RMS Incidents beginning June 1, 2014 to current-date. It disseminates police report information in a timely, accurate manner. This information reflects crimes as reported to the Dallas Police Department as of Sep 7, 2018. Crime classifications are based upon preliminary information supplied to the Dallas Police Department by the reporting parties and the preliminary classifications may be changed at a later date based upon additional investigation.
#
# The data set suppresses sexually oriented offenses, offenses where juveniles or children are the victim or suspect, property items that are considered evidence, Social Service Referral offenses, and identifying vehicle information in certain offenses for the sake of security.
#
# ### Business Objectives
#
# Reviewing and analyzing the data set would help us track 911 calls in the Dallas region
#  - by Division,
#  - Analyzing victim type,
#  - Track the conversion rate of dispatches to arrests by priority of calls,
#  - Median dispatch time by division.
#
# ### Success criteria
#
#
#
#
#
#
#
#
#
# Our analysis focused on identifying and tracking crime patterns and classifying data into meaningful groups based on type of crime and associated response times. Furthermore, we wanted to examine the impact of population demographics by stratifying crimes based on age, sex and ethnicity. Another question of interest was the seasonality of crime cycles in the Dallas area and a deeper analysis of victim profiles.

# %% [markdown]
# - Track crime, Classification time, Response time
#
# - Arrests made
#
# - Victim profile analysis (minors, adult, race, ethnicity)
#
# - Seasonality of crime cycles - based on days, months and years
#
# - Response times relative to Location and Population density
#
# - Cross validation, Dividing the data set into test and train

# %% [markdown]
# ## Data Meaning Type
#
# [Click to see codes](#Importing Datasets)

# %% [markdown]
# In Dallas police incident dataset, it has 469,927 entries with 100 variables. The full schema of this dataset can be found at <a href="https://www.dallasopendata.com/Public-Safety/Police-Incidents/qv6i-rri7"/>  here. </a> We only selected 43 variables for our analysis and 57 attributes we eleminated in our analysis due to below reasons:
# - Some redundant information like incident number, we can eaily parse from service number field to get the incident year and number of offense on the incident.
# - Some information like address, apartment number, etc. are out of scope of our analysis.
# - And some attribues has a lot of missing values, like Victim Package, Criminal Justice Information Service Code, etc.
#
# Please see below the definition of the attribute we selected for our analysis:
#
# Attribute|Data Type|Description|%missing
# :--------- | :----------------- | :-------------               | :---------
# <p align="left">Service_Number_ID</p>|Norminal|<p align="left">Incident number plus year code plus offense number (Ex: -02 means there is two offense with this one incident) Internal use</p>|0.00
# <p align="left">Watch</p>|Norminal|<p align="left">Police watch 1st 2nd or 3rd (1st watch = Late Night, 2nd watch = Days and 3rd watch = Evenings)</p>|0.00
# <p align="left">Type_of_Incident</p>|Norminal|<p align="left">Type of Incident</p>|0.00
# <p align="left">Type_Location</p>|Norminal|<p align="left">Location type where incident took place For example, Apartment Parking, Residence</p>|2.67
# <p align="left">Reporting Area</p>|Norminal|<p align="left">Geographic area comprised of reporting areas where incident occurred</p>|0.12
# <p align="left">Beat</p>|Norminal|<p align="left">Geographic area comprised of beats where incident occurred ( the city broken down for patrol and statistical purposes)</p>|0.05
# <p align="left">Division</p>|Norminal|<p align="left">Geographic area comprised of census blocks where incident occurred (smallest police geography)</p>|0.05
# <p align="left">Sector</p>|Norminal|<p align="left">Geographic area comprised of Sectors where incident occurred</p>|0.04
# <p align="left">Council_District</p>|Norminal|<p align="left">Geographic area comprised of city council districts where incident occurred</p>|0.43
# <p align="left">Date1_of_Occurrence</p>|Interval|<p align="left">The first date of the date occurrence of the incident (Ex: incident occurred between 1/1/2016 and 1/2/2016)</p>|0.00
# <p align="left">Day1_of_the_Week</p>|Interval|<p align="left">Day of the indent based on the Date of Occurrence (Date1). Internal use</p>|0.00
# <p align="left">Time1_of_Occurrence</p>|Interval|<p align="left">The first (starting) time of the time occurrence of the incident (Ex: incident occurred between 8:00am and 5:00pm)</p>|0.00
# <p align="left">Date2_of_Occurrence</p>|Interval|<p align="left">The second date of the date occurrence of the incident (Ex: incident occurred between 1/1/2016 and 1/2/2016)</p>|0.00
# <p align="left">Day2_of_the_Week</p>|Interval|<p align="left">Day of the indent based on the Date of Occurrence (Date2)</p>|0.00
# <p align="left">Time2_of_Occurrence</p>|Interval|<p align="left">The second(end) time of the time occurrence of the incident (Ex: incident occurred between 8:00am and 5:00pm)</p>|0.00
# <p align="left">Call_Received_Date_Time</p>|Interval|<p align="left">The date the related call was received</p>|0.40
# <p align="left">Call_Date_Time</p>|Interval|<p align="left">Date and time of the related call</p>|0.40
# <p align="left">Call_Cleared_Date_Time</p>|Interval|<p align="left">Date and time related call was cleared</p>|0.47
# <p align="left">Call_Dispatch_Date_Time</p>|Interval|<p align="left">Date and time related call was dispatched</p>|0.41
# <p align="left">Person_Involvement_Type</p>|Norminal|<p align="left">Person can be; 'Victim', 'Registered Owner', 'Owner', nan,'Passenger', 'Driver','Reporting Person', 'Witness', 'Victim/RP'</p>|3.46
# <p align="left">Victim_Type</p>|Norminal|<p align="left">Victim Type</p>|5.22
# <p align="left">Victim_Race</p>|Norminal|<p align="left">Race</p>|34.53
# <p align="left">Victim_Ethnicity</p>|Norminal|<p align="left">Victim Ethnicity</p>|35.13
# <p align="left">Victim_Gender</p>|Norminal|<p align="left">Victim Gender</p>|34.50
# <p align="left">Victim_Age</p>|Ratio|<p align="left">Victim Age</p>|38.01
# <p align="left">Victim_Age_at_Offense</p>|Ratio|<p align="left">Victim Age at Offense</p>|38.74
# <p align="left">Victim_Zip_Code</p>|Norminal|<p align="left">Victim Zip Code</p>|7.96
# <p align="left">Victim_City</p>|Norminal|<p align="left">Victim City</p>|6.46
# <p align="left">Victim_State</p>|Norminal|<p align="left">Victim State</p>|7.53
# <p align="left">Offense_Status</p>|Norminal|<p align="left">Status of the offense. Values: 'Suspended', 'Clear by Arrest', 'Clear by Exceptional Arrest','Open', 'Closed/Cleared', nan, 'SW', 'D','Returned for Correction', 'CL',W'</p>|2.03
# <p align="left">UCR_Disposition</p>|Norminal|<p align="left">UCR Disposition of the incident</p>|2.01
# <p align="left">Family_Offense</p>|Interval|<p align="left">Yes or no if the offense is family violence</p>|0.02
# <p align="left">Hate_Crime</p>|Interval|<p align="left">Yes or no if offense is a hate crime</p>|99.88
# <p align="left">Weapon_Used</p>|Interval|<p align="left">Weapon Used</p>|15.78
# <p align="left">Gang_Related_Offense</p>|Interval|<p align="left">Yes or no if offense is gang realated</p>|15.67
# <p align="left">Drug_Related_Istevencident</p>|Interval|<p align="left">Yes or no if incident is drug related</p>|0.03
# <p align="left">RMS_Code</p>|Norminal|<p align="left">UCR Offense code</p>|0.00
# <p align="left">UCR_Code</p>|Norminal|<p align="left">UCR Code</p>|8.87
# <p align="left">X_Coordinate</p>|Interval|<p align="left">X Coordinate</p>|10.98
# <p align="left">Y_Cordinate</p>|Interval|<p align="left">Y Cordinate</p>|10.98
# <p align="left">Zip_Code</p>|Norminal|<p align="left">Zipcode in which incident occured</p>|0.74
# <p align="left">City</p>|Norminal|<p align="left">City in which incident occurred</p>|1.04
# <p align="left">Location1</p>|Norminal|<p align="left">Incident Location has X cordinate and Y cordinate</p>|0.71
#
#
# In the incident record, call received date/time, call leared date/time and call dispatch date/time will be used to calculate the police responce time. we will use that value to find the relationship between the police response time and the incident location, incident type, incident time (morning, evening or night), witness involved or not ect. Person_Involvement_Type can be used to analysis if the response time fast if there is the witness involved int.
#
# Time series can be apply for each UCR crime type which season is happened more often.

# %% [markdown]
# ## Data Quality
#
# [Click to see codes](#Exploring Data Quality)

# %% [markdown]
# We did an analysis of the percentage of missing values in our dataset by attribute to understand the extent of the issue with the subset we selected.  Given the large data set of 466K observations, we felt that the impact of some missing values in certain attributes would not significantly impact our analysis.
# - Explain missing data values
#     + Hate_Crime: There are only 376 values in this attribute
#     + Victim_Age: By design the ages of juveniles and minors have been willfully eliminated from the dataset due to sensitivity reasons
#     + Victim_Age_at_Offense:Missing values are for the same reason as listed above
#     + Victim_Race:Missing values were tagged as Unknown
#     + Victim_Gender:Missing values were tagged as Unknown
#     + Missing values in the Victim_City attribute were assigned a value of "DALLAS" given the dataset is primarily focused on the Dallas area
#
# - Duplicate data
#
# - Outliers
#
# - Standardization
#     + Division was standardized by making all values upper caps for improved grouping
#     + Sector was standardized to address mistakes where the leading "D" was missing and values lined up to the correct division
#     + Victim_Race was aligned with the US Census Bureau standards on race and ethnicity as below.  However, we did deviate from the US Census categories and retained Latino or Hispanic as a distinct ethnic group and did not merge it with American Indian or Alaska Native
#
#         * **White** – A person having origins in any of the original peoples of Europe, the Middle East, or North Africa.
#
#         * **Black or African American** – A person having origins in any of the Black racial groups of Africa.
#
#         * **American Indian or Alaska Native** – A person having origins in any of the original peoples of North and South America (including Central America) and who maintains tribal affiliation or community attachment.
#
#         * **Asian** – A person having origins in any of the original peoples of the Far East, Southeast Asia, or the Indian subcontinent including, for example, Cambodia, China, India, Japan, Korea, Malaysia, Pakistan, the Philippine Islands, Thailand, and Vietnam.
#
#         * **Native Hawaiian or Other Pacific Islander** – A person having origins in any of the original peoples of Hawaii, Guam, Samoa, or other Pacific Islands.
#
#         * **Latino or Hispanic** –
#
# - (Source: US Census Bureau)
#
# - Reasons for mistakes in data
#     + Some mistakes in the data were clearly attributable to typos by either officers or dispatchers but were easily cleaned up such as sector, year, division etc.
#
# - Deletion and imputation

# %% [markdown]
# ## Simple Statistics

# %% [markdown]
# - General stats table
# - General visualization

# %% [markdown]
# ## Visualize Attributes
#
#
# [Click here to see visualizations and code](#Visualize Attributes)

# %% [markdown]
# To better understand and represent key findings we used graphical components from pandas, matlab, PixieDust and even Power BI.  This enabled a much richer presentation of the facts and findings.
#
# + **Arrest Status:** Arrests made against incidents reported and investigated.  This was best represented using a horizontal barchart.
#
# + **Watch:** Categorizes which shifts or watch had the most reported incidents in the day.It is evident from the visual that Late night incidents are the highest followed by Evenings and Day.
#
# + **Call Dispatch:**
#
# + **Division:** Incidents by Police Division gave insight into which areas in Dallas have the highest reported incidents
#
# + **NIBRS Offense Codes:** Based on the horizontal barchart we can see that Larceny, Property damage, Burglary, Assault and Vehicle thefts are the top 5 crimes in the Dallas area. We then also graphed reported incidents by their UCR codes and the results were fairly similar except that Assault seemed to be missing in the top 5 (excluding OTHER).

# %% [markdown]
# ## Explore Joint Attributes
#
# <a id='Back6'></a>
# [Click to see visulaizations and code](#Explore Joint Attributes)

# %% [markdown]
# WRITE SOMETHING.....

# %% [markdown]
# ## Explore Attributes and Class

# %% [markdown]
# WRITE SOMETHING.....

# %% [markdown]
# ## New Features

# %% [markdown]
# WRITE SOMETHING.....

# %% [markdown]
# ## Exceptional Work

# %% [markdown]
# To complement our Police Incident dataset we imported the following datasetsto provide greater insight for our analysis.  This enabled us to better understand arrest rates against incidents as well as population factors that play a critical role in effective policing a large metropolitan city like DALLAS.
#
# - **Police Arrests dataset**
# - **Population Density dataset**
#
# We Geo-Mapped the data using Zip codes to provide an enhanced visualization of crime pockets in the Dallas area. Additionally, we standardized by linking our data to the FBI National Incident-Based Reporting Systems (NIBRS) standarized Offense Codes available <a href="https://ucr.fbi.gov/nibrs/2011/resources/nibrs-offense-codes"/>  here</a>.
#
# There are two categories of offenses reported in the NIBRS: Group A and Group B. It is important to determine which category an offense belongs to because the reporting
# requirements for Group A offenses and Group B offenses are different. Group A offenses are used to report all incidents committed within a law enforcement agency’s jurisdiction to the
# NIBRS, whereas Group B offenses are used only to report arrest data.
# The following criteria were used to determine if a crime should be designated as a Group A offense:
# - The seriousness or significance of the offense.
# - The frequency or volume of its occurrence.
# - The prevalence of the offense nationwide.
# - The probability of the offense being brought to law enforcement’s attention.
# - The likelihood that law enforcement is the best channel for collecting data regarding the offense.
# - The burden placed on law enforcement to collect data on the offense.
# - The national statistical validity and usefulness of the collected data.
# - The FBI UCR Program’s responsibility to make crime data available not only to law enforcement but to others having a legitimate interest in it.
#
# There are 22 Group A offense categories making up 46 Group A offenses. Each offense’s corresponding UCR Offense Code precedes its name. Immediately following the name of each offense name is an indication of whether it involves a Crime Against Person, Crime Against Property, or Crime Against Society.
#
# There are 11 Group B offense categories. They encompass all of the crimes that are not Group A offenses.
#
# (Source:FBI.gov) )

# %% [markdown]
# # ELIMINATE

# %% [markdown]
# WRITE SOMETHING

# %% [markdown]
# ###### REFERENCE FOR CODING PURPOSE

# %% [markdown]
# BINS CODE FOR CHANGING LAT LONG
#
# dx = (lon2-lon1)*40000*math.cos((lat1+lat2)*math.pi/360)/360
# dy = (lat1-lat2)*40000/360

# %% [markdown]
# #### Importing packages

# %%
# Importing necessary packages for python
import pandas as pd
import numpy as np
import datetime
import time
import string
from dateutil.relativedelta import relativedelta
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.cross_validation import StratifiedKFold
# from sklearn import metrics as mt
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
pd.set_option('mode.chained_assignment', None)
plt.style.use('ggplot')
import seaborn as sns

# %% [markdown]
# ### Importing Datasets
#
# <a id='Importing Datasets'></a>
#
# [Go Back](#Back)

# %%
# LOADING DATA INTO DATAFRAME

# MAIN DATA SET- Incident dataset as of  SEP 5, 2018
path = "../Data/" # Generic path
incident_Origin = pd.read_csv(path + 'Police_Incidents.csv', low_memory=False)

# SUPPORTING DATA SETS FOR FUTURE USE
# Dallas area population dataset
population = pd.read_csv(path + 'Population.csv', low_memory=False)
# Dallas area police station dataset
police_station = pd.read_csv(path + 'Dallas_Police_Stations.csv', low_memory=False)
# Police arrest records for crosss reference
police_arrest = pd.read_csv(path + 'Police_arrests.csv', low_memory=False)

# %%
incident_Origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469927 entries, 0 to 469926
# Data columns (total 100 columns):
# Incident Number w/year                       469927 non-null object
# Year of Incident                             469927 non-null int64
# Service Number ID                            469927 non-null object
# Watch                                        469927 non-null object
# Call (911) Problem                           468058 non-null object
# Type of Incident                             469927 non-null object
# Type  Location                               457381 non-null object
# Type of Property                             114560 non-null object
# Incident Address                             466603 non-null object
# Apartment Number                             89425 non-null object
# Reporting Area                               469366 non-null float64
# Beat                                         469710 non-null float64
# Division                                     469710 non-null object
# Sector                                       469719 non-null float64
# Council District                             467897 non-null object
# Target Area Action Grids                     157645 non-null object
# Community                                    50284 non-null object
# Date1 of Occurrence                          469923 non-null object
# Year1 of Occurrence                          469923 non-null float64
# Month1 of Occurence                          469923 non-null object
# Day1 of the Week                             469923 non-null object
# Time1 of Occurrence                          469923 non-null object
# Day1 of the Year                             469923 non-null float64
# Date2 of Occurrence                          469922 non-null object
# Year2 of Occurrence                          469922 non-null float64
# Month2 of Occurence                          469922 non-null object
# Day2 of the Week                             469922 non-null object
# Time2 of Occurrence                          469922 non-null object
# Day2 of the Year                             469922 non-null float64
# Date of Report                               469927 non-null object
# Date incident created                        469927 non-null object
# Offense Entered Year                         469927 non-null int64
# Offense Entered Month                        469927 non-null object
# Offense Entered Day of the Week              469927 non-null object
# Offense Entered Time                         469927 non-null object
# Offense Entered  Date/Time                   469927 non-null int64
# CFS Number                                   468059 non-null object
# Call Received Date Time                      468059 non-null object
# Call Date Time                               468059 non-null object
# Call Cleared Date Time                       467724 non-null object
# Call Dispatch Date Time                      468015 non-null object
# Special Report (Pre-RMS)                     2717 non-null object
# Person Involvement Type                      453646 non-null object
# Victim Type                                  445375 non-null object
# Victim Name                                  450277 non-null object
# Victim Race                                  307657 non-null object
# Victim Ethnicity                             304838 non-null object
# Victim Gender                                307818 non-null object
# Victim Age                                   291326 non-null float64
# Victim Age at Offense                        287871 non-null float64
# Victim Home Address                          440084 non-null object
# Victim Apartment                             125567 non-null object
# Victim Zip Code                              432529 non-null float64
# Victim City                                  439582 non-null object
# Victim State                                 434526 non-null object
# Victim Business Name                         18717 non-null object
# Victim Business Address                      11988 non-null object
# Victim Business Phone                        6521 non-null object
# Responding Officer #1  Badge No              467481 non-null object
# Responding Officer #1  Name                  466688 non-null object
# Responding Officer #2 Badge No               170541 non-null object
# Responding Officer #2  Name                  170539 non-null object
# Reporting Officer Badge No                   468686 non-null object
# Assisting Officer Badge No                   355821 non-null object
# Reviewing Officer Badge No                   467955 non-null object
# Element Number Assigned                      467632 non-null object
# Investigating Unit 1                         345848 non-null object
# Investigating Unit 2                         345878 non-null object
# Offense Status                               460408 non-null object
# UCR Disposition                              460471 non-null object
# Victim Injury Description                    27198 non-null object
# Victim Condition                             22398 non-null object
# Modus Operandi (MO)                          445450 non-null object
# Family Offense                               469820 non-null object
# Hate Crime                                   587 non-null object
# Hate Crime Description                       469787 non-null object
# Weapon Used                                  395751 non-null object
# Gang Related Offense                         396299 non-null object
# Victim Package                               0 non-null float64
# Drug Related Istevencident                   469773 non-null object
# RMS Code                                     469927 non-null object
# Criminal Justice Information Service Code    469927 non-null int64
# Penal Code                                   469927 non-null object
# UCR Offense Name                             428687 non-null object
# UCR Offense Description                      428687 non-null object
#  UCR Code                                    428687 non-null float64
# Offense Type                                 428687 non-null object
# NIBRS Crime                                  196568 non-null object
# NIBRS Crime Category                         196568 non-null object
# NIBRS Crime Against                          196568 non-null object
# NIBRS Code                                   196568 non-null object
# NIBRS Group                                  196568 non-null object
# NIBRS Type                                   196568 non-null object
# Update Date                                  469927 non-null object
# X Coordinate                                 418307 non-null float64
# Y Cordinate                                  418307 non-null float64
# Zip Code                                     466432 non-null float64
# City                                         465029 non-null object
# State                                        465486 non-null object
# Location1                                    466603 non-null object
# dtypes: float64(15), int64(4), object(81)
# memory usage: 358.5+ MB

# %%
# Keeping only the attributes we want to be in our analysis
incident= incident_Origin[['Incident Number w/year','Year of Incident', 'Service Number ID','Watch', 'Type of Incident', 
                           'Type  Location','Reporting Area', 'Beat', 'Division', 'Sector', 'Council District', 
                           'Date of Report','Date incident created', 'Offense Entered  Date/Time',
                           'Call Received Date Time','Call Cleared Date Time','Call Dispatch Date Time', 
                           'Person Involvement Type', 'Victim Type', 'Victim Race', 'Victim Gender', 'Victim Age',
                           'Victim State','Offense Status','Victim Condition', 'Hate Crime', 'Weapon Used',
                           'Gang Related Offense','Drug Related Istevencident','UCR Offense Name',' UCR Code', 
                           'X Coordinate', 'Y Cordinate','Zip Code', 'City','State','Location1']] 
                           
# Replacing some columns with 2 whitespaces with one
incident.rename(columns=lambda x: x.replace('  ', ' '), inplace=True) 
# Replacing all whitespaces with '_'
incident.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
incident = incident.rename(columns = {'_UCR_Code':'UCR_Code', 'Y_Cordinate':'Y_Coordinate'})

# %%
# Data head and attribute information before the clean up.
print(incident.info())
incident.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469927 entries, 0 to 469926
# Data columns (total 37 columns):
# Incident_Number_w/year        469927 non-null object
# Year_of_Incident              469927 non-null int64
# Service_Number_ID             469927 non-null object
# Watch                         469927 non-null object
# Type_of_Incident              469927 non-null object
# Type_Location                 457381 non-null object
# Reporting_Area                469366 non-null float64
# Beat                          469710 non-null float64
# Division                      469710 non-null object
# Sector                        469719 non-null float64
# Council_District              467897 non-null object
# Date_of_Report                469927 non-null object
# Date_incident_created         469927 non-null object
# Offense_Entered_Date/Time     469927 non-null int64
# Call_Received_Date_Time       468059 non-null object
# Call_Cleared_Date_Time        467724 non-null object
# Call_Dispatch_Date_Time       468015 non-null object
# Person_Involvement_Type       453646 non-null object
# Victim_Type                   445375 non-null object
# Victim_Race                   307657 non-null object
# Victim_Gender                 307818 non-null object
# Victim_Age                    291326 non-null float64
# Victim_State                  434526 non-null object
# Offense_Status                460408 non-null object
# Victim_Condition              22398 non-null object
# Hate_Crime                    587 non-null object
# Weapon_Used                   395751 non-null object
# Gang_Related_Offense          396299 non-null object
# Drug_Related_Istevencident    469773 non-null object
# UCR_Offense_Name              428687 non-null object
# UCR_Code                      428687 non-null float64
# X_Coordinate                  418307 non-null float64
# Y_Coordinate                  418307 non-null float64
# Zip_Code                      466432 non-null float64
# City                          465029 non-null object
# State                         465486 non-null object
# Location1                     466603 non-null object
# dtypes: float64(8), int64(2), object(27)
# memory usage: 132.7+ MB
# None
#   Incident_Number_w/year  Year_of_Incident Service_Number_ID Watch  \
# 0            234975-2017              2017    234975-2017-01     1
# 1            179463-2017              2017    179463-2017-01     U
# 2            175975-2016              2016    175975-2016-01     1
#
#                              Type_of_Incident               Type_Location  \
# 0      ASSAULT (AGG) -PUB SERV (AGG, LAW ENF)  Highway, Street, Alley ETC
# 1  UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE    Parking Lot (All Others)
# 2                                         BMV               Motor Vehicle
#
#    Reporting_Area   Beat   Division  Sector  \
# 0          4048.0  424.0  SOUTHWEST   420.0
# 1          2019.0  156.0    CENTRAL   150.0
# 2          3104.0  542.0  NORTHWEST   540.0
#
#                          ...                         Gang_Related_Offense  \
# 0                        ...                                           No
# 1                        ...                                           No
# 2                        ...                                           No
#
#   Drug_Related_Istevencident   UCR_Offense_Name  UCR_Code  X_Coordinate  \
# 0                         No  AGG ASSAULT - NFV     400.0           NaN
# 1                        UNK               UUMV     710.0  2.498099e+06
# 2                         No          THEFT/BMV     640.0  2.482440e+06
#
#    Y_Coordinate Zip_Code    City State  \
# 0           NaN      NaN     NaN   NaN
# 1  6.978035e+06  75204.0  DALLAS    TX
# 2  6.986586e+06  75235.0  DALLAS    TX
#
#                                            Location1
# 0                                                NaN
# 1  4500 LIVE OAK ST\nDALLAS, TX 75204\n(32.799576...
# 2  3136 HUDNALL ST\nDALLAS, TX 75235\n(32.823936,...
#
# [3 rows x 37 columns]

# %% [markdown]
# ### Exploring Data Quality
#
# <a id='Exploring Data Quality'></a>
#
# [Go Back](#Back)

# %%
# CHECKING FOR BIN'S CODE FOR MISSING DATA INFORMATION
incident_NullCols = incident.isnull().sum()
incident_NullCols = incident_NullCols[incident_NullCols > 0]
incident_NullCols = pd.DataFrame({'n Missing' : incident_NullCols,
                                  '% Missing' : ((incident_NullCols / incident.shape[0])*100).round(2)})

cm = sns.light_palette("red", as_cmap=True)
incident_NullCols.style.background_gradient(cmap=cm)


# MARKUP ADD
# Out:
# <style  type="text/css" >
#     #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow0_col0 {
#             background-color:  #ffe0e0;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow0_col1 {
#             background-color:  #ffe0e0;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow1_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow1_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow2_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow2_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow3_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow3_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow4_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow4_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow5_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow6_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow6_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow7_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow7_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow8_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow8_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow9_col0 {
#             background-color:  #ffdede;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow9_col1 {
#             background-color:  #ffdede;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow10_col0 {
#             background-color:  #ffdada;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow10_col1 {
#             background-color:  #ffdada;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow11_col0 {
#             background-color:  #ff9696;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow11_col1 {
#             background-color:  #ff9696;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow12_col0 {
#             background-color:  #ff9696;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow12_col1 {
#             background-color:  #ff9696;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow13_col0 {
#             background-color:  #ff8e8e;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow13_col1 {
#             background-color:  #ff8e8e;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow14_col0 {
#             background-color:  #ffd4d4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow14_col1 {
#             background-color:  #ffd4d4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow15_col0 {
#             background-color:  #ffe1e1;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow15_col1 {
#             background-color:  #ffe1e1;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow16_col0 {
#             background-color:  #ff0a0a;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow16_col1 {
#             background-color:  #ff0a0a;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow17_col0 {
#             background-color:  #ff0000;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow17_col1 {
#             background-color:  #ff0000;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow18_col0 {
#             background-color:  #ffc2c2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow18_col1 {
#             background-color:  #ffc2c2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow19_col0 {
#             background-color:  #ffc2c2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow19_col1 {
#             background-color:  #ffc2c2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow20_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow20_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow21_col0 {
#             background-color:  #ffd2d2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow21_col1 {
#             background-color:  #ffd2d2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow22_col0 {
#             background-color:  #ffd2d2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow22_col1 {
#             background-color:  #ffd2d2;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow23_col0 {
#             background-color:  #ffcccc;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow23_col1 {
#             background-color:  #ffcccc;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow24_col0 {
#             background-color:  #ffcccc;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow24_col1 {
#             background-color:  #ffcccc;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow25_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow25_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow26_col0 {
#             background-color:  #ffe4e4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow26_col1 {
#             background-color:  #ffe4e4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow27_col0 {
#             background-color:  #ffe4e4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow27_col1 {
#             background-color:  #ffe4e4;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow28_col0 {
#             background-color:  #ffe5e5;
#         }    #T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow28_col1 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >% Missing</th>
#         <th class="col_heading level0 col1" >n Missing</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13flevel0_row0" class="row_heading level0 row0" >Type_Location</th>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow0_col0" class="data row0 col0" >2.67</td>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow0_col1" class="data row0 col1" >12546</td>
#     </tr>    <tr>
#         <th id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13flevel0_row1" class="row_heading level0 row1" >Reporting_Area</th>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow1_col0" class="data row1 col0" >0.12</td>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow1_col1" class="data row1 col1" >561</td>
#     </tr>    <tr>
#         <th id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13flevel0_row2" class="row_heading level0 row2" >Beat</th>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow2_col0" class="data row2 col0" >0.05</td>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow2_col1" class="data row2 col1" >217</td>
#     </tr>    <tr>
#         <th id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13flevel0_row3" class="row_heading level0 row3" >Division</th>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow3_col0" class="data row3 col0" >0.05</td>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow3_col1" class="data row3 col1" >217</td>
#     </tr>    <tr>
#         <th id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13flevel0_row4" class="row_heading level0 row4" >Sector</th>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow4_col0" class="data row4 col0" >0.04</td>
#         <td id="T_d7ee010c_b6ee_11e8_851f_c85b76fac13frow4_col1" clas

# %% [markdown]
# The data above shows percentage of missing or null values along with number of missing values from the original dataset for selected columns for out analysis.
#
# ---

# %% [markdown]
# ## Dataset exploration and cleaning
#
# - This section includes codes for exploration of data, cleanup, and creation of new attributes.
#
# [Go Back](#Back)

# %% [markdown]
# # LIST NEW FEATURES AND DESCRIPTION AFTER THIS

# %% [markdown]
# ##### *  NOTES

# %% [markdown]
# |TO CLEAN | Cleaned | NEW | DROP
# | --- | --- | --- | --- |
# |'Incident_Number_w/year'| | | N |
# |'Year_of_Incident'| Year_of_Incident | | N |
# |'Service_Number_ID'| Service_Number_ID | Number_of_offense | Y |
# |'Watch'| Watch | | N |
# |'Type_of_Incident'| | | U |
# |'Type_Location'| | | N |
# |'Reporting_Area'| | | N |
# |'Beat'| | | N |
# |'Division'| Division | | N |
# |'Sector'| | | N |
# |'Council_District'| Council_District | | N |
# |'Date_of_Report'| | | U |
# |'Date_incident_created'| | | U |
# |'Offense_Entered_Date/Time'| | | U |
# |'Call_Received_Date_Time'| Call_Received_Date_Time | Call_Received,Response_time | Y |
# |'Call_Cleared_Date_Time'| Call_Cleared_Date_Time | | Y |
# |'Call_Dispatch_Date_Time'| Call_Dispatch_Date_Time | Call_Dispatch, Response_time| Y |
# |'Person_Involvement_Type'| | | N |
# |'Victim_Type'| Victim_Type | | N |
# |'Victim_Race'| Victim_Race | | N |
# |'Victim_Gender'| Victim_Gender | | N |
# |'Victim_Age'| | | U |
# |'Victim_State'| | | U |
# |'Offense_Status'| Offense_Status | Arrest_status | Y |
# |'Victim_Condition'| Victim_Condition | | N |
# |'Hate_Crime'| Hate_Crime | | N |
# |'Weapon_Used'| | | U |
# |'Gang_Related_Offense'| Gang_Related_Offense | | N |
# |'Drug_Related_Istevencident'| Drug_Related_Istevencident | | N |
# |'UCR_Offense_Name'| | | U |
# |'UCR_Code'| UCR_Code | | N |
# |'X_Coordinate'| X_Coordinate | | U |
# |'Y_Cordinate'| Y_Coordinate | | U |
# |'Zip_Code'| Zip_Code | | N |
# |'City'| City | | N|
# |'State'| | | Y |
# |'Location1'| Location1 | Latitude,Longitude | Y |

# %%
# incident['Type_of_Incident']

# %%
# incident['Type_Location'].unique()

# %% [markdown]
# ### CODE TO CLEAN

# %%
# Clean up the Victim Types
incident.loc[incident['Victim_Type'] == 'Person', 'Victim_Type'] = 'Individual'
incident.loc[incident['Victim_Type'] == 'na', 'Victim_Type'] = 'Unknown'
incident['Victim_Type'].fillna('Unknown', inplace=True)
incident.fillna('Unknown').groupby(['Victim_Type'])['Service_Number_ID'].count().plot(kind='barh')

# %% [markdown]
# COMMENT: Sort the values

# %%
# COUNCIL DISTRICT
incident.loc[:,'Council_District']= incident['Council_District'].replace("D","", regex=True)
incident.loc[:,'Council_District']= incident['Council_District'].fillna("OTHER")
incident.loc[:,'Council_District']= "D-"+incident['Council_District'].astype(str)
incident.groupby(['Council_District'])['Service_Number_ID'].count()
# Out:
# Council_District
# D-1        24565
# D-10       29164
# D-11       27523
# D-12       15726
# D-13       26763
# D-14       43173
# D-2        50378
# D-3        27728
# D-4        36217
# D-5        25540
# D-6        48801
# D-7        47449
# D-8        41035
# D-9        23835
# D-OTHER     2030
# Name: Service_Number_ID, dtype: int64

# %%
# NORMALIZING THE DISTANCE AND COORDINATES
incident.loc[:,'X_Coordinate'] = incident[np.isfinite(incident['X_Coordinate'])]
incident.loc[:,'Y_Coordinate'] = incident[np.isfinite(incident['Y_Coordinate'])]

incident.loc[:,'Zip_Code'] = incident['Zip_Code'].fillna(0).astype(int)  # "O" being missing values

# %%
incident.loc[:,'City'] = incident['City'].fillna("MISSING")

city_replace = dict.fromkeys(['Dallas','DALAS','DALLS','DALLLAS','DALLA','DLS',
                              'DALALS','D','DAL','DLLAS','DSLLAS','DALLAST','DAQLLAS'], 'DALLAS')

incident.loc[:,'City']= incident['City'].replace(city_replace)

# %%
incident['Type_Location'].unique()
# Out:
# array(['Highway, Street, Alley ETC', 'Parking Lot (All Others)',
#        'Motor Vehicle', 'Other', 'Apartment Parking Lot',
#        'Business Office', 'Single Family Residence - Occupied',
#        'Commercial Property Occupied/Vacant', nan,
#        'Apartment Complex/Building', 'Outdoor Area Public/Private',
#        'Medical Facility', 'Storage Facility', 'Apartment Residence',
#        'Parking Lot (Apartment)', 'Single Family Residence - Vacant',
#        'Industrial/Manufacturing', 'Gas or Service Station',
#        'Restaurant/Food Service/TABC Location', 'Retail Store',
#        'City Park/Rec/Tennis/Golf/Trail', 'Convenience Store',
#        'Parking Lot (Park)', 'Government Facility',
#        'Financial Institution', 'Condominium/Townhome Residence',
#        'Condominium/Townhome Building', 'Bar/NightClub/DanceHall ETC.',
#        'Condominium/Townhome Parking', 'Airport - All Others',
#        'Airport - Love Field', 'Entertainment/Sports Venue',
#        'School/Daycare', 'Religious Institution', 'Personal Services'],
#       dtype=object)

# %%
incident.loc[:,'Year_of_Incident'].value_counts()

# = incident['Year_of_Incident'] !=2918
# Out:
# 2016    93313
# 2015    86751
# 2017    86502
# 2018    70356
# 2014    51287
# Name: Year_of_Incident, dtype: int64

# %%
print(incident['Victim_Gender'].unique())
print("Cleaned Victim Gender Type")
incident['Victim_Gender'] = np.where(incident['Victim_Gender']=='Male', "M",
                                     np.where(incident['Victim_Gender']=='Female', "F", "U"))

print(incident['Victim_Gender'].unique())
# Out:
# ['Male' nan 'Female' 'Unknown' 'TEST' 'N']
# Cleaned Victim Gender Type
# ['M' 'U' 'F']

# %%
# JUST CHECKING ON UCR CODE (MAIN DATAFRAME UNCHANGED)
incident['UCR_Code'].fillna(0).astype(int, error='ignore').unique()

# USE UCR_CODE INSTEAD TO SUMMARIZE

print(incident['Watch'].unique())
incident[incident['Watch'].isnull()==True]
# WRITE ANNOTATION FOR NUMBERS
incident.loc[:,'Watch'] = np.where(incident['Watch']=='U', '0', incident['Watch']).astype(int)
incident['Watch'].unique()
# Out:
# ['1' 'U' '2' '3']
# array([1, 0, 2, 3], dtype=int64)

# %%
# Coding Binary variables for some columns  
def get_binary_code(row):
    if row == 'Yes':
        return 1
    else:
        return 0

    
# Arrest_status variable binary coding
def get_status(row):
    if row['Offense_Status']=='Clear by Arrest':
        return 1
    elif row['Offense_Status']=='Clear by Exceptional Arrest':
        return 1
    else:
        return 0

# %%
print(incident['Victim_Race'].unique())

# # change the missing value and do the mapping
incident.loc[incident['Victim_Race'] == 'American Indian / Native American', 'Victim_Race'] = 'Native_American'
incident.loc[incident['Victim_Race'] == 'American Indian/Native American', 'Victim_Race'] = 'Native_American'
incident.loc[incident['Victim_Race'] == 'Asian or Pacific Islander', 'Victim_Race'] = 'Hawaiian_Pacific_Islander'
incident.loc[incident['Victim_Race'] == 'Native Hawaiian or Pacific Islander', 'Victim_Race'] = 'Hawaiian_Pacific_Islander'
incident.loc[incident['Victim_Race'] == 'Latin / Hispanic', 'Victim_Race'] = 'Latin_Hispanic'
incident.loc[incident['Victim_Race'] == 'Latin/Hispanic', 'Victim_Race'] = 'Latin_Hispanic'
incident.loc[incident['Victim_Race'] == 'TEST', 'Victim_Race'] = 'Unknown'
incident.loc[incident['Victim_Race'] == 'N', 'Victim_Race'] = 'Unknown'
incident['Victim_Race'].fillna('Unknown', inplace=True)

incident['Victim_Race'].value_counts()

# # one hot encoding for race (try this method for getting scores)
# tmp_df = pd.get_dummies(incident.Victim_Race,prefix='Race')
# incident = pd.concat((incident,tmp_df),axis=1)
# Out:
# ['White' nan 'Latin/Hispanic' 'Black' 'Middle Eastern' 'Asian' 'Unknown'
#  'Native Hawaiian or Pacific Islander' 'American Indian/Native American'
#  'TEST' 'Latin / Hispanic' 'Asian or Pacific Islander' 'N'
#  'American Indian / Native American']
# Unknown                      165280
# Black                        104988
# Latin_Hispanic                98064
# White                         90828
# Asian                          5346
# Middle Eastern                 4608
# Native_American                 468
# Hawaiian_Pacific_Islander       345
# Name: Victim_Race, dtype: int64

# %%
incident.loc[:,'Victim_Condition'] = incident['Victim_Condition'].fillna("Unknown")
incident['Victim_Condition'].value_counts()
# Out:
# Unknown     447529
# Good         14304
# Stable        4628
# Deceased      2601
# Serious        581
# Critical       284
# Name: Victim_Condition, dtype: int64

# %%
# Converting Division to upper case as names are in different cases
incident.loc[:,'Division']=incident['Division'].str.upper()
incident.loc[:,'Division'].fillna('Unknown', inplace=True)

# Converting string to datetimes

incident.loc[:,'Call_Received']= pd.to_datetime(incident['Call_Received_Date_Time'], 
                                                format="%m/%d/%Y %I:%M:%S %p")
incident.loc[:,'Call_Cleared']= pd.to_datetime(incident['Call_Cleared_Date_Time'], 
                                               format="%m/%d/%Y %I:%M:%S %p")
incident.loc[:,'Call_Dispatch']= pd.to_datetime(incident['Call_Dispatch_Date_Time'], 
                                                format="%m/%d/%Y %I:%M:%S %p")

# %%
# Parsing number of offenses per incident from 'Service_Number_ID' data definition
incident.loc[:,'Number_of_offense']= incident['Service_Number_ID'].str.split("-",
                                                                             expand=True).rename(columns = {2:'Number_of_offense'})


# incident.loc[:,'Year_of_offense']= incident['Service_Number_ID'].str.split("-",
#                                                                              expand=True).rename(columns = {1:'Year_of_offense'})

# Calulcating response time from Call Received to Call dispatch from original columns 'Call_Received_Date_Time' and 'Call_Dispatch_Date_Time'
incident.loc[:,'Response_time'] = pd.Series(data=(incident['Call_Dispatch']-incident['Call_Received']).astype('timedelta64[m]').astype('float'),
                                          index=incident.index,name='Response_Time')


# Parsing Latitude and Longitude from 'Location1 attribute which was in mixed form of variables 
incident.loc[:,'Latitude']= incident['Location1'].str.split("\n",
                                                            expand=True)[2].str.split(',',
                                                                                      expand=True)[0].str.split('(',
                                                                                                                expand=True).rename(columns = {1 : 'Latitude'}).astype(int, errors='ignore')
                                                                                                  
incident.loc[:,'Longitude']= incident['Location1'].str.split("\n",
                                                            expand=True)[2].str.split(',',
                                                                                      expand=True)[1].str.split(')',
                                                                                                                expand=True).rename(columns = {0 : 'Longitude'}).astype(int, errors='ignore')


# Incident arrest status based on "Offense_Status" columns
incident.loc[:,'Arrest_status']= incident.apply(get_status, axis=1)    
# Applying Binary Coding to these attributes
incident.loc[:,'Hate_Crime'] = incident['Hate_Crime'].apply(get_binary_code)
incident.loc[:,'Gang_Related_Offense'] = incident['Gang_Related_Offense'].apply(get_binary_code)
incident.loc[:,'Drug_Related_Istevencident'] = incident['Drug_Related_Istevencident'].apply(get_binary_code)

# %%
incident['Number_of_offense'].value_counts()

## RP = reported again (repeated) MORE VICTIMS
# Out:
# 01    366543
# 02     16198
# 03      3041
# 04       972
# RP       766
# 05       330
# 06       153
# 07        80
# 08        44
# 09        30
# 10        19
# 11        13
# 12         7
# 13         4
# 14         3
# 21         1
# 17         1
# 20         1
# 15         1
# 22         1
# 18         1
# 19         1
# 16         1
# Name: Number_of_offense, dtype: int64

# %%
incident['Response_time'].describe()
# Out:
# count    388211.000000
# mean         44.369742
# std          73.968715
# min           1.000000
# 25%           5.000000
# 50%          15.000000
# 75%          52.000000
# max        1438.000000
# Name: Response_time, dtype: float64

# %%
# Since Response time cannot be negative and cannot be larger than 24 hrs, removing those records
# Assumption: Response time from call received to dispatch should be within 0-1440 minutes (i.e. 24 hrs)

incident = incident[incident['Response_time']> 0]
incident = incident[incident['Response_time'] < 1441] 

# Expalin the urgent time and emergent time

# %%
incident['Response_time'].describe()
# Out:
# count    388209.000000
# mean         44.369901
# std          73.968869
# min           1.000000
# 25%           5.000000
# 50%          15.000000
# 75%          52.000000
# max        1438.000000
# Name: Response_time, dtype: float64

# %% [markdown]
# FROM CALL RECEIVED TO DISPATCH, assuming 24 hrs data
# - Average response time is now 44 minutes

# %%
incident.groupby(['Year_of_Incident'])['Response_time'].median()
# Out:
# Year_of_Incident
# 2014    18.0
# 2015    18.0
# 2016    12.0
# 2017    16.0
# 2018    13.0
# Name: Response_time, dtype: float64

# %% [markdown]
# - Response time in minutes can't be negative
#
# Discuss on removing those values
#
# ####
# The exploratory statistics on the response time calculated proved to be more insightful in creating this attribute since time and date alone did not provide us with answering underlying questions we wanted to answer.
#
# COmparing with national statistics of resposne time ((((LINK)))))), Dallas average response time in terms of median response time is about 16 minutes in 2017 and 13 minutes in 2018 and counting.
#
# Some of the missing values, unusual data values is detected while calculating respose time merely because of data recording errors. In such case, the solution can be implemented simply by assuming by taking analyzing any data that had response time within 24 hours for any emergency or by performing simple statistical procedures.
#
# The statistical summary of mean, std, min,max, IQR(25%,50%,75%)provided us with some more information on how to deal with these situation. The histogram is plotted to get better understanding and visualization of the distributions.
#
# LABEL AND DEFINE ALL HISTOGRAMS

# %%
incident[['Response_time', 'Year_of_Incident']].hist(bins=5, color='lightblue', edgecolor='black', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2)) 
plt.show()

# .plot(kind='hist')

# %%
sns.violinplot(x=incident["Response_time"], palette = 'Set3')
plt.show()

# %%
print(incident['Year_of_Incident'].value_counts())
incident= incident[incident['Year_of_Incident']!=2108]
incident= incident[incident['Year_of_Incident']!=2918]
# Out:
# 2016    93313
# 2015    86751
# 2017    86502
# 2018    70356
# 2014    51287
# Name: Year_of_Incident, dtype: int64

# %%
plt.subplots(figsize = (12,9))
plt.scatter(incident['Year_of_Incident'], incident['Response_time'], color='blue');
plt.plot(incident.groupby(['Year_of_Incident'])['Response_time'].median(), color = 'red', linewidth = 4)
plt.show()

# %%
# incident.hist(bins=15, color='darkturquoise', edgecolor='black', linewidth=1.0,
#            xlabelsize=8, ylabelsize=8, grid=False)  
# plt.show()

# %%
incident.groupby(['Year_of_Incident'])['Response_time'].median()
# Out:
# Year_of_Incident
# 2014    18.0
# 2015    18.0
# 2016    12.0
# 2017    16.0
# 2018    13.0
# Name: Response_time, dtype: float64

# %%
plt.subplots(figsize = (12,9))
plt.scatter(incident['Year_of_Incident'], incident['Response_time'], color='blue');
plt.plot(incident.groupby(['Year_of_Incident'])['Response_time'].mean(), color = 'red', linewidth = 4)
plt.show()

# %% [markdown]
# ## REDUCED DATAFRAME

# %% [markdown]
# #### PLEASE UTILIZE THIS CELL FOR REDUCTION OF DATAFRAME FROM THIS POINT

# %%
# #### PLEASE UTILIZE THIS CELL FOR REDUCTION OR ADDITION OF ATTRIBUTES OF DATAFRAME FROM THIS POINT

# incident= incident.drop(['Incident_Number_w/year', 'Year_of_Incident', 'Service_Number_ID',
#        'Watch', 'Type_of_Incident', 'Type_Location', 'Reporting_Area', 'Beat',
#        'Division', 'Sector', 'Council_District', 'Person_Involvement_Type', 'Victim_Type',
#        'Victim_Race', 'Victim_Gender', 'Victim_Age', 'Victim_State',
#        'Offense_Status', 'Victim_Condition', 'Hate_Crime', 'Weapon_Used',
#        'Gang_Related_Offense', 'Drug_Related_Istevencident',
#        'UCR_Offense_Name', 'UCR_Code', 'X_Coordinate', 'Y_Cordinate',
#        'Zip_Code', 'City', 'State', 'Y_Coordinate',
#        'Call_Received', 'Call_Cleared', 'Call_Dispatch', 'Number_of_offense',
#        'Response_time', 'Latitude', 'Longitude', 'Arrest_status'], axis=1)

# %% [markdown]
# ### Visualize Attributes
#
# <a id='Visualize Attributes'></a>
#
# [Go Back](#Back)

# %%
incident['Division'].fillna('***MISSING***').value_counts().plot('barh')

# %%
incident['Division'].value_counts().plot(kind='pie', legend=False)

# CENTERED AND WIDER WE NEED TO ADD PERCENTAGE OF INCIDENT COUNT

# %%
incident['Arrest_status'].value_counts().plot(kind='barh', legend= True)

# 1 means arrested

# %%
#

# %%
# 1st watch = Late Night, 2nd watch = Days and 3rd watch = Evenings
incident['Watch'].value_counts().plot(kind='bar', legend=True)

# %% [markdown]
# Late night crimes are more prevalent and frequent as per data which is generally accepted from the social dynamics. Criminals try to hide behind darkness of night.

# %%
incident['Call_Dispatch'].value_counts().plot(kind='line', legend=True)


# MAKE IT WIDER

# %% [markdown]
# From this graph, it looks like the similar spike trend is seen between 2017-06 to 2018-06 which was seen between 2014-06 to 2015-06. We will need to look further into data about seasonality factor into the crime rates and call dispactch tom be sure. However, longer nights in fall points to the fact that there is some kind of relation between time of the day or darness hours to crime ratio.
#
#
# 24 hrs seasonality

# %%
incident['Type_Location'].value_counts().plot(kind='barh', legend=True)


# BIN PLEASE LOOK INTO THIS ATTRIBUTE, REDUCE CATEGORIES

# %% [markdown]
# - Downtown metroplex
# - Full of alleys so it is obvious.
# - Texas has more highways thus also self explanatory

# %% [markdown]
# ### Explore Joint Attributes
#
# <a id='Explore Joint Attributes'></a>
#
# [Go Back](#Back6)

# %%
# CUSTOM VIRTUALIZATION DICTIONARY
def hover_to_see_data():
    return [dict(selector="th",
                 props=[("font-size", "8pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])]

inci_numeric = incident.select_dtypes(exclude=['object'])
inciCorrMat = inci_numeric.corr()
inciCorrMat.style.background_gradient(sns.diverging_palette(240, 10, as_cmap=True), axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Correlation Heatmap for numeric variables")\
    .set_precision(2)\
    .set_table_styles(hover_to_see_data())
# Out:
# <style  type="text/css" >
#     #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13f th {
#           font-size: 8pt;
#     }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13f td {
#           padding: 0em 0em;
#     }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13f th:hover {
#           font-size: 12pt;
#     }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13f tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col0 {
#             background-color:  #da3b46;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col1 {
#             background-color:  #94b6ce;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col2 {
#             background-color:  #8cb0ca;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col3 {
#             background-color:  #8db1cb;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col4 {
#             background-color:  #8db1cb;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col5 {
#             background-color:  #417ca8;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col6 {
#             background-color:  #8db1cb;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col7 {
#             background-color:  #8cb0ca;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col8 {
#             background-color:  #89aec9;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col9 {
#             background-color:  #91b4cd;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col10 {
#             background-color:  #99b9d0;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col11 {
#             background-color:  #89aec9;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col12 {
#             background-color:  #8db1cb;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col13 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col14 {
#             background-color:  #83aac6;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow0_col15 {
#             background-color:  #94b6ce;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col0 {
#             background-color:  #5d8fb4;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col1 {
#             background-color:  #da3b46;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col2 {
#             background-color:  #588cb2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col3 {
#             background-color:  #588cb2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col4 {
#             background-color:  #588cb2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col5 {
#             background-color:  #5288af;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col6 {
#             background-color:  #417ca8;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col7 {
#             background-color:  #558ab1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col8 {
#             background-color:  #588cb2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col9 {
#             background-color:  #6695b9;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col10 {
#             background-color:  #85abc7;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col11 {
#             background-color:  #5c8eb4;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col12 {
#             background-color:  #4b83ac;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col13 {
#             background-color:  #5187af;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col14 {
#             background-color:  #437da8;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow1_col15 {
#             background-color:  #79a3c2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col0 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col1 {
#             background-color:  #a1bed4;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col2 {
#             background-color:  #da3b46;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col3 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col4 {
#             background-color:  #f2f2f2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col5 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col6 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col7 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col8 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col9 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col10 {
#             background-color:  #9bbbd2;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col11 {
#             background-color:  #417ca8;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col12 {
#             background-color:  #78a2c1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col13 {
#             background-color:  #9ebdd3;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ca77e7c0_b6f1_11e8_968a_c85b76fac13frow2_col14 {
#             background-color:

# %%
corrPairs = inciCorrMat.unstack().sort_values(kind="quicksort")

# %%
corrPairs = corrPairs[::2]
corrPairs = corrPairs[corrPairs.index.get_level_values(0) != corrPairs.index.get_level_values(1)]
with pd.option_context('display.max_rows',32):
    print(corrPairs)
# Out:
# Sector                      X_Coordinate                 -0.426252
# Beat                        X_Coordinate                 -0.424072
# Reporting_Area              X_Coordinate                 -0.354116
# Offense_Entered_Date/Time   Year_of_Incident             -0.266644
# Reporting_Area              Y_Coordinate                 -0.144405
# Y_Coordinate                Beat                         -0.126299
#                             Sector                       -0.124645
# Arrest_status               Response_time                -0.094844
# UCR_Code                    Response_time                -0.065915
# Watch                       Victim_Age                   -0.056872
# Response_time               Watch                        -0.049672
# Drug_Related_Istevencident  Response_time                -0.045336
# Arrest_status               UCR_Code                     -0.041071
# Victim_Age                  Arrest_status                -0.038110
# Zip_Code                    Arrest_status                -0.038097
# Victim_Age                  Y_Coordinate                 -0.031808
#                                                             ...
# Watch                       Year_of_Incident              0.028853
# Gang_Related_Offense        Drug_Related_Istevencident    0.035502
# Response_time               Offense_Entered_Date/Time     0.037359
# Year_of_Incident            UCR_Code                      0.041570
# Drug_Related_Istevencident  Watch                         0.050612
# Sector                      Victim_Age                    0.055362
# Victim_Age                  Beat                          0.055483
# Year_of_Incident            Zip_Code                      0.060756
# Victim_Age                  UCR_Code                      0.063563
# Arrest_status               Watch                         0.109956
# Drug_Related_Istevencident  Arrest_status                 0.118776
# UCR_Code                    Drug_Related_Istevencident    0.127446
# Watch                       UCR_Code                      0.142013
# Reporting_Area              Beat                          0.342876
#                             Sector                        0.343086
# Beat                        Sector                        0.999942
# Length: 120, dtype: float64

# %%
incident[incident.Watch == 0].groupby(['Year_of_Incident'])['Response_time'].median()
# Out:
# Year_of_Incident
# 2014    31.0
# 2015    33.0
# 2016    22.0
# 2017    32.0
# 2018    32.0
# Name: Response_time, dtype: float64

# %%
sns.pairplot(incident, vars=['Response_time','Watch'], hue='Arrest_status')

# %%
sns.pairplot(incident.dropna(), vars=['Response_time', 'X_Coordinate', 'Y_Coordinate','Watch'], hue='Arrest_status')

# %% [markdown]
# The columns with highest importance relate to response time.
#
# Legend
# - Blue: represents the arrest made during incident which are closely clustered with lower respose time.
# The arrest is more likely when response time is quicker, which is supported from other graphs as well.

# %%
sns.boxplot(x='Victim_Race', y='Victim_Age', data=incident.dropna())

# %%
# REMOVE OUTLIERS AND CLEAN

# incident.loc[:,'Victim_Age']= incident['Victim_Age']

# %% [markdown]
# ROUGH STATS FROM GRAPH: Arrest was made when there was less response time, probebly beacuse of nature of crime or incident. Higher the response time less emergent, no arrest was made. Negatively correlated -0.094 something..CHECK!!!

# %%
sns.factorplot(x="Division", y="Response_time", hue="Arrest_status", col="Watch", data=incident, join= False , palette="Set1",size=7, aspect=1.1)
plt.show()

# %% [markdown]
# - Response time by Division and from wat 0 to 4
# - From the plots above, it does not seem as though there is a significant relationship between whether or not a response time and time of the day played factor in arrest made.......

# %%
# BIN'S POWER BI MAP

# %% [markdown]
# - Please see below map report for the dallas crime distribute by zip code in 2017. The more read means more crime. Zip code 75217 has the most crime in 2017 (6027 incident calls) and zip code 75115 has the least crime (only 1 incident report in 2017).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # MORE FUNCTIONS

# %%
# def outlier_elim_sdt(df, columns_list):
#     '''
#     This function identifies outliers, using mean +/- 2STDev and reports the index of the row
#     the list of indices can then be used to eliminate the rows with outliers. 
#     '''
#     outliers_all = np.array([], dtype='int64')
#     for column in columns_list:
#         LOW  = df[column].mean() - (2*df[column].std())
#         HIGH = df[column].mean() + (2*df[column].std())
#         out_list_feat = list(df[~((df[column] >= LOW) & (df[column] <= HIGH))].index)
#         outliers_all  = np.append(outliers_all, out_list_feat)
#     out_count = Counter(outliers_all)
#     out_customer = []
#     for customer, count in out_count.items():
#         if count > 0:#1:
#             out_customer.append(customer.astype(int))
#     outliers  = list(sorted(out_customer))
#     return outliers

    
    
# outlier_decision(incident, columns_list=['Response_time'])

# %%
# # import plotly.plotly as ply
# # import cufflinks as cf
# incident1= incident.copy()
# incident1.index = pd.to_datetime(incident1.index)
# incident1.columns = ['Response_time']

# incident1.iplot(title="Response....seasonality")

# %%
# # from plotly.plotly import plot_mpl
# from statsmodels.tsa.seasonal import seasonal_decompose
# result = seasonal_decompose(incident, model='multiplicative')
# fig = result.plot()
# plot_mpl(fig)
